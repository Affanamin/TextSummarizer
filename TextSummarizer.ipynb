# %% [markdown]
# <a href="https://colab.research.google.com/github/Affanamin/TextSummarizer/blob/master/TextSummarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re
from nltk.corpus import stopwords
import time
from tensorflow.python.layers.core import Dense
from tensorflow.python.ops.rnn_cell_impl import _zero_state_tensors

# %%
#print('TensorFlow Version: {}'.format(tf.__version__))

# %%
#!apt-get install -y -qq software-properties-common python-software-properties module-init-tools
#!wget https://launchpad.net/~alessandro-strada/+archive/ubuntu/google-drive-ocamlfuse-beta/+build/15331130/+files/google-drive-ocamlfuse_0.7.0-0ubuntu1_amd64.deb
#!dpkg -i google-drive-ocamlfuse_0.7.0-0ubuntu1_amd64.deb
#!apt-get install -f
#!apt-get -y install -qq fuse

# %%
# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
# Out:
# Requirement already satisfied: pyunpack in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: easyprocess in /usr/local/lib/python3.6/dist-packages (from pyunpack) (0.2.10)
# Requirement already satisfied: patool in /usr/local/lib/python3.6/dist-packages (1.12)

# %%
Archive('/content/drive/My Drive/amazon-fine-food-reviews.zip').extractall('TextSum')

# %%
data_train=pd.read_csv('TextSum/Reviews.csv')

# %%
data_train.shape
# Out:
# (568454, 10)

# %%
data_train.head(2)
# Out:
#    Id  ...                                               Text
# 0   1  ...  I have bought several of the Vitality canned d...
# 1   2  ...  Product arrived labeled as Jumbo Salted Peanut...
#
# [2 rows x 10 columns]

# %%
# Check for any nulls values
data_train.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               16
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
data_train = data_train.dropna()

# %%
data_train = data_train.drop(['Id','ProductId','UserId','ProfileName','HelpfulnessNumerator','HelpfulnessDenominator','Score','Time'],axis =1)

# %%
data_train = data_train.reset_index(drop=True)

# %%
data_train.head(5)
# Out:
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
# Inspecting some of the reviews
for i in range(5):
    print("Review #",i+1)
    print(data_train.Summary[i])
    print(data_train.Text[i])
    print()
# Out:
# Review # 1
# Good Quality Dog Food
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
#
# Review # 2
# Not as Advertised
# Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
#
# Review # 3
# "Delight" says it all
# This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with powdered sugar.  And it is a tiny mouthful of heaven.  Not too chewy, and very flavorful.  I highly recommend this yummy treat.  If you are familiar with the story of C.S. Lewis' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to the Witch.
#
# Review # 4
# Cough Medicine
# If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.
#
# Review # 5
# Great taffy
# Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.

# %% [markdown]
# Preparing The data:::
#
# We gonna clean the text first, then tokenize it , clean unwanted words.

# %%
# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions = { 
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'll": "i will",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"must've": "must have",
"mustn't": "must not",
"needn't": "need not",
"oughtn't": "ought not",
"shan't": "shall not",
"sha'n't": "shall not",
"she'd": "she would",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"that'd": "that would",
"that's": "that is",
"there'd": "there had",
"there's": "there is",
"they'd": "they would",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"wasn't": "was not",
"we'd": "we would",
"we'll": "we will",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"where'd": "where did",
"where's": "where is",
"who'll": "who will",
"who's": "who is",
"won't": "will not",
"wouldn't": "would not",
"you'd": "you would",
"you'll": "you will",
"you're": "you are"
}

# %%
def clean_text(text, remove_stopwords = True):
    # Convert words to lower case
    text = text.lower()
    # Replace contractions with their longer forms 
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
    
    # Format words and remove unwanted characters
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = re.sub(r'\<a href', ' ', text)
    text = re.sub(r'&amp;', '', text) 
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'\'', ' ', text)
    
    # Optionally, remove stop words
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text

# %%
import nltk
nltk.download('stopwords')
  
# Clean the summaries and texts
clean_summaries = []
for summary in data_train.Summary:
    clean_summaries.append(clean_text(summary, remove_stopwords=False))
print("Summaries are complete.")

clean_texts = []
for text in data_train.Text:
    clean_texts.append(clean_text(text))
print("Texts are complete.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Summaries are complete.
# Texts are complete.

# %%
# Inspect the cleaned summaries and texts to ensure they have been cleaned well
for i in range(5):
    print("Clean Review #",i+1)
    print(clean_summaries[i])
    print(clean_texts[i])
    print()
# Out:
# Clean Review # 1
# good quality dog food
# bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
#
# Clean Review # 2
# not as advertised
# product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
#
# Clean Review # 3
#  delight  says it all
# confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story c lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
#
# Clean Review # 4
# cough medicine
# looking secret ingredient robitussin believe found got addition root beer extract ordered good made cherry soda flavor medicinal
#
# Clean Review # 5
# great taffy
# great taffy great price wide assortment yummy taffy delivery quick taffy lover deal

# %%
def count_words(count_dict, text):
    #Count the number of occurrences of each word in a set of text
    for sentence in text:
        for word in sentence.split():
            if word not in count_dict:
                count_dict[word] = 1
            else:
                count_dict[word] += 1

# %%
# Find the number of times each word was used and the size of the vocabulary
word_counts = {}
print("Size of Vocabulary1:", len(word_counts))
count_words(word_counts, clean_summaries)
count_words(word_counts, clean_texts)
            
print("Size of Vocabulary:", len(word_counts))
# Out:
# Size of Vocabulary1: 0
# Size of Vocabulary: 132884

# %%
Archive('/content/drive/My Drive/numberbatch-en-19.08.txt.gz').extractall('TextSum')

# %%
# Load Conceptnet Numberbatch's (CN) embeddings, similar to GloVe, but probably better 
# (https://github.com/commonsense/conceptnet-numberbatch)
embeddings_index = {}
with open('TextSum/numberbatch-en.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split(' ')
        word = values[0]
        embedding = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = embedding

print('Word embeddings:', len(embeddings_index))
# Out:
# Word embeddings: 516783

# %%
# Find the number of words that are missing from CN, and are used more than our threshold.
missing_words = 0
threshold = 20

for word, count in word_counts.items():
    if count > threshold:
        if word not in embeddings_index:
            missing_words += 1
            
missing_ratio = round(missing_words/len(word_counts),4)*100
            
print("Number of words missing from CN:", missing_words)
print("Percent of words that are missing from vocabulary: {}%".format(missing_ratio))
# Out:
# Number of words missing from CN: 3845
# Percent of words that are missing from vocabulary: 2.8899999999999997%

# %% [markdown]
# I use a threshold of 20, so that words not in CN can be added to our word_embedding_matrix, but they need to be common enough in the reviews so that the model can understand their meaning.

# %%
# Limit the vocab that we will use to words that appear ≥ threshold or are in GloVe

#dictionary to convert words to integers
vocab_to_int = {} 

value = 0
for word, count in word_counts.items():
    if count >= threshold or word in embeddings_index:
        vocab_to_int[word] = value
        value += 1

# Special tokens that will be added to our vocab
codes = ["<UNK>","<PAD>","<EOS>","<GO>"]   

# Add codes to vocab
for code in codes:
    vocab_to_int[code] = len(vocab_to_int)

# Dictionary to convert integers to words
int_to_vocab = {}
for word, value in vocab_to_int.items():
    int_to_vocab[value] = word

usage_ratio = round(len(vocab_to_int) / len(word_counts),4)*100

print("Total number of unique words:", len(word_counts))
print("Number of words we will use:", len(vocab_to_int))
print("Percent of words we will use: {}%".format(usage_ratio))
# Out:
# Total number of unique words: 132884
# Number of words we will use: 60433
# Percent of words we will use: 45.48%

# %%
# Need to use 300 for embedding dimensions to match CN's vectors.
embedding_dim = 300
nb_words = len(vocab_to_int)

# Create matrix with default values of zero
word_embedding_matrix = np.zeros((nb_words, embedding_dim), dtype=np.float32)
for word, i in vocab_to_int.items():
    if word in embeddings_index:
        word_embedding_matrix[i] = embeddings_index[word]
    else:
        # If word not in CN, create a random embedding for it
        new_embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
        embeddings_index[word] = new_embedding
        word_embedding_matrix[i] = new_embedding

# Check if value matches len(vocab_to_int)
print(len(word_embedding_matrix))
# Out:
# 60433

# %%
def convert_to_ints(text, word_count, unk_count, eos=False):
    '''Convert words in text to an integer.
       If word is not in vocab_to_int, use UNK's integer.
       Total the number of words and UNKs.
       Add EOS token to the end of texts'''
    ints = []
    for sentence in text:
        sentence_ints = []
        for word in sentence.split():
            word_count += 1
            if word in vocab_to_int:
                sentence_ints.append(vocab_to_int[word])
            else:
                sentence_ints.append(vocab_to_int["<UNK>"])
                unk_count += 1
        if eos:
            sentence_ints.append(vocab_to_int["<EOS>"])
        ints.append(sentence_ints)
    return ints, word_count, unk_count

# %%
word_count = 0
unk_count = 0

int_summaries, word_count, unk_count = convert_to_ints(clean_summaries, word_count, unk_count)
int_texts, word_count, unk_count = convert_to_ints(clean_texts, word_count, unk_count, eos=True)

unk_percent = round(unk_count/word_count,4)*100

print("Total number of words in headlines:", word_count)
print("Total number of UNKs in headlines:", unk_count)
print("Percent of words that are UNK: {}%".format(unk_percent))
# Out:
# Total number of words in headlines: 25679933
# Total number of UNKs in headlines: 189830
# Percent of words that are UNK: 0.74%

# %%
def create_lengths(text):
    '''Create a data frame of the sentence lengths from a text'''
    lengths = []
    for sentence in text:
        lengths.append(len(sentence))
    return pd.DataFrame(lengths, columns=['counts'])

# %%
lengths_summaries = create_lengths(int_summaries)
lengths_texts = create_lengths(int_texts)

print("Summaries:")
print(lengths_summaries.describe())
print()
print("Texts:")
print(lengths_texts.describe())
# Out:
# Summaries:
#               counts
# count  568411.000000
# mean        4.181624
# std         2.657872
# min         0.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max        48.000000
#
# Texts:
#               counts
# count  568411.000000
# mean       41.996835
# std        42.520873
# min         1.000000
# 25%        18.000000
# 50%        29.000000
# 75%        50.000000
# max      2085.000000

# %%
# Inspect the length of texts
print(np.percentile(lengths_texts.counts, 90))
print(np.percentile(lengths_texts.counts, 95))
print(np.percentile(lengths_texts.counts, 99))
# Out:
# 84.0
# 115.0
# 207.0

# %%
# Inspect the length of summaries
print(np.percentile(lengths_summaries.counts, 90))
print(np.percentile(lengths_summaries.counts, 95))
print(np.percentile(lengths_summaries.counts, 99))
# Out:
# 8.0
# 9.0
# 13.0

# %%
def unk_counter(sentence):
    '''Counts the number of time UNK appears in a sentence.'''
    unk_count = 0
    for word in sentence:
        if word == vocab_to_int["<UNK>"]:
            unk_count += 1
    return unk_count

# %%
# takes a long time  , this is normal

# Sort the summaries and texts by the length of the texts, shortest to longest
# Limit the length of summaries and texts based on the min and max ranges.
# Remove reviews that include too many UNKs

sorted_summaries = []
sorted_texts = []
max_text_length = 84
max_summary_length = 13
min_length = 2
unk_text_limit = 1
unk_summary_limit = 0

for length in range(min(lengths_texts.counts), max_text_length): 
    for count, words in enumerate(int_summaries):
        if (len(int_summaries[count]) >= min_length and
            len(int_summaries[count]) <= max_summary_length and
            len(int_texts[count]) >= min_length and
            unk_counter(int_summaries[count]) <= unk_summary_limit and
            unk_counter(int_texts[count]) <= unk_text_limit and
            length == len(int_texts[count])
           ):
            sorted_summaries.append(int_summaries[count])
            sorted_texts.append(int_texts[count])
        
# Compare lengths to ensure they match
print(len(sorted_summaries))
print(len(sorted_texts))
# Out:
# 425974
# 425974

# %% [markdown]
# ***Building the Model***

# %%
def model_inputs():
    '''Create palceholders for inputs to the model'''
    
    input_data = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    lr = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    summary_length = tf.placeholder(tf.int32, (None,), name='summary_length')
    max_summary_length = tf.reduce_max(summary_length, name='max_dec_len')
    text_length = tf.placeholder(tf.int32, (None,), name='text_length')

    return input_data, targets, lr, keep_prob, summary_length, max_summary_length, text_length

# %%
def process_encoding_input(target_data, vocab_to_int, batch_size):
    '''Remove the last word id from each batch and concat the <GO> to the begining of each batch'''
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], vocab_to_int['<GO>']), ending], 1)

    return dec_input

# %%
def encoding_layer(rnn_size, sequence_length, num_layers, rnn_inputs, keep_prob):
    '''Create the encoding layer'''
    
    for layer in range(num_layers):
        with tf.variable_scope('encoder_{}'.format(layer)):
            cell_fw = tf.contrib.rnn.LSTMCell(rnn_size,
                                              initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            cell_fw = tf.contrib.rnn.DropoutWrapper(cell_fw, 
                                                    input_keep_prob = keep_prob)

            cell_bw = tf.contrib.rnn.LSTMCell(rnn_size,
                                              initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            cell_bw = tf.contrib.rnn.DropoutWrapper(cell_bw, 
                                                    input_keep_prob = keep_prob)

            enc_output, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw, 
                                                                    cell_bw, 
                                                                    rnn_inputs,
                                                                    sequence_length,
                                                                    dtype=tf.float32)
    # Join outputs since we are using a bidirectional RNN
    enc_output = tf.concat(enc_output,2)
    
    return enc_output, enc_state

# %%
def training_decoding_layer(dec_embed_input, summary_length, dec_cell, initial_state, output_layer, 
                            vocab_size, max_summary_length):
    '''Create the training logits'''
    
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=summary_length,
                                                        time_major=False)

    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       initial_state,
                                                       output_layer) 

    training_logits, _ , _ = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                           output_time_major=False,
                                                           impute_finished=True,
                                                           maximum_iterations=max_summary_length)
    return training_decoder

# %%
def inference_decoding_layer(embeddings, start_token, end_token, dec_cell, initial_state, output_layer,
                             max_summary_length, batch_size):
    '''Create the inference logits'''
    
    start_tokens = tf.tile(tf.constant([start_token], dtype=tf.int32), [batch_size], name='start_tokens')
    
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embeddings,
                                                                start_tokens,
                                                                end_token)
                
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        initial_state,
                                                        output_layer)
                
    inference_logits, _ , _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                            output_time_major=False,
                                                            impute_finished=True,
                                                            maximum_iterations=max_summary_length)
    
    return inference_decoder

# %%
def decoding_layer(dec_embed_input, embeddings, enc_output, enc_state, vocab_size, text_length, summary_length, 
                   max_summary_length, rnn_size, vocab_to_int, keep_prob, batch_size, num_layers):
    '''Create the decoding cell and attention for the training and inference decoding layers'''
    
    for layer in range(num_layers):
        with tf.variable_scope('decoder_{}'.format(layer)):
            lstm = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
            dec_cell = tf.contrib.rnn.DropoutWrapper(lstm, 
                                                     input_keep_prob = keep_prob)
    
    output_layer = Dense(vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    attn_mech = tf.contrib.seq2seq.BahdanauAttention(rnn_size,
                                                  enc_output,
                                                  text_length,
                                                  normalize=False,
                                                  name='BahdanauAttention')

    dec_cell = tf.contrib.seq2seq.AttentionWrapper(dec_cell,
                                                          attn_mech,
                                                          rnn_size)
            
    #initial_state = tf.contrib.seq2seq.AttentionWrapperState(enc_state[0],
    #                                                                _zero_state_tensors(rnn_size, 
    #                                                                                    batch_size, 
    #                                                                                    tf.float32)) 
    initial_state = dec_cell.zero_state(batch_size=batch_size,dtype=tf.float32).clone(cell_state=enc_state[0])

    with tf.variable_scope("decode"):
        training_decoder = training_decoding_layer(dec_embed_input, 
                                                  summary_length, 
                                                  dec_cell, 
                                                  initial_state,
                                                  output_layer,
                                                  vocab_size, 
                                                  max_summary_length)
        
        training_logits,_ ,_ = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                  output_time_major=False,
                                  impute_finished=True,
                                  maximum_iterations=max_summary_length)
    with tf.variable_scope("decode", reuse=True):
        inference_decoder = inference_decoding_layer(embeddings,  
                                                    vocab_to_int['<GO>'], 
                                                    vocab_to_int['<EOS>'],
                                                    dec_cell, 
                                                    initial_state, 
                                                    output_layer,
                                                    max_summary_length,
                                                    batch_size)
        
        inference_logits,_ ,_ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                  output_time_major=False,
                                  impute_finished=True,
                                  maximum_iterations=max_summary_length)

    return training_logits, inference_logits

# %%
def seq2seq_model(input_data, target_data, keep_prob, text_length, summary_length, max_summary_length, 
                  vocab_size, rnn_size, num_layers, vocab_to_int, batch_size):
    '''Use the previous functions to create the training and inference logits'''
    
    # Use Numberbatch's embeddings and the newly created ones as our embeddings
    embeddings = word_embedding_matrix
    
    enc_embed_input = tf.nn.embedding_lookup(embeddings, input_data)
    enc_output, enc_state = encoding_layer(rnn_size, text_length, num_layers, enc_embed_input, keep_prob)
    
    dec_input = process_encoding_input(target_data, vocab_to_int, batch_size)
    dec_embed_input = tf.nn.embedding_lookup(embeddings, dec_input)
    
    training_logits, inference_logits  = decoding_layer(dec_embed_input, 
                                                        embeddings,
                                                        enc_output,
                                                        enc_state, 
                                                        vocab_size, 
                                                        text_length, 
                                                        summary_length, 
                                                        max_summary_length,
                                                        rnn_size, 
                                                        vocab_to_int, 
                                                        keep_prob, 
                                                        batch_size,
                                                        num_layers)
    
    return training_logits, inference_logits

# %%
def pad_sentence_batch(sentence_batch):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [vocab_to_int['<PAD>']] * (max_sentence - len(sentence)) for sentence in sentence_batch]

# %%
def get_batches(summaries, texts, batch_size):
    """Batch summaries, texts, and the lengths of their sentences together"""
    for batch_i in range(0, len(texts)//batch_size):
        start_i = batch_i * batch_size
        summaries_batch = summaries[start_i:start_i + batch_size]
        texts_batch = texts[start_i:start_i + batch_size]
        pad_summaries_batch = np.array(pad_sentence_batch(summaries_batch))
        pad_texts_batch = np.array(pad_sentence_batch(texts_batch))
        
        # Need the lengths for the _lengths parameters
        pad_summaries_lengths = []
        for summary in pad_summaries_batch:
            pad_summaries_lengths.append(len(summary))
        
        pad_texts_lengths = []
        for text in pad_texts_batch:
            pad_texts_lengths.append(len(text))
        
        yield pad_summaries_batch, pad_texts_batch, pad_summaries_lengths, pad_texts_lengths

# %%
# Set the Hyperparameters
epochs = 100
batch_size = 64
rnn_size = 256
num_layers = 2
learning_rate = 0.005
keep_probability = 0.75

# %%
# Build the graph
train_graph = tf.Graph()
# Set the graph to default to ensure that it is ready for training
with train_graph.as_default():
    
    # Load the model inputs    
    input_data, targets, lr, keep_prob, summary_length, max_summary_length, text_length = model_inputs()

    # Create the training and inference logits
    training_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                      targets, 
                                                      keep_prob,   
                                                      text_length,
                                                      summary_length,
                                                      max_summary_length,
                                                      len(vocab_to_int)+1,
                                                      rnn_size, 
                                                      num_layers, 
                                                      vocab_to_int,
                                                      batch_size)
    
    # Create tensors for the training logits and inference logits
    training_logits = tf.identity(training_logits.rnn_output, 'logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')
    
    # Create the weights for sequence_loss
    masks = tf.sequence_mask(summary_length, max_summary_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)
print("Graph is built.")
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-44-9390cb26606a>:7: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-44-9390cb26606a>:20: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Graph is built.

# %% [markdown]
# **Training the Model**

# %% [markdown]
# Since I am training this model on my MacBook Pro, it would take me days if I used the whole dataset. For this reason, I am only going to use a subset of the data, so that I can train it over night. Normally I use FloydHub's services for my GPU needs, but it would take quite a bit of time to upload the dataset and ConceptNet Numberbatch, so I'm not going to bother with that for this project.
#
# I chose not use use the start of the subset because I didn't want to make it too easy for my model. The texts that I am using are closer to the median lengths; I thought this would be more fair.

# %%
# Train the Model
learning_rate_decay = 0.95
min_learning_rate = 0.0005
display_step = 20 # Check training loss after every 20 batches
stop_early = 0 
stop = 6 #3 # If the update loss does not decrease in 3 consecutive update checks, stop training
per_epoch = 3 # Make 3 update checks per epoch
update_check = (len(sorted_texts)//batch_size//per_epoch)-1

update_loss = 0 
batch_loss = 0
summary_update_loss = [] # Record the update losses for saving improvements in the model

  
tf.reset_default_graph()
#checkpoint = "drive/Colab Notebooks/Menu/Model 300/best_model.ckpt"  #300k sentence

checkpoint = "/content/drive/My Drive/best_model_300.ckpt"  #300k sentence
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
    
    # If we want to continue training a previous session
    # loader = tf.train.import_meta_graph(checkpoint + '.meta')
    # loader.restore(sess, checkpoint)
    #sess.run(tf.local_variables_initializer())

    for epoch_i in range(1, epochs+1):
        update_loss = 0
        batch_loss = 0
        for batch_i, (summaries_batch, texts_batch, summaries_lengths, texts_lengths) in enumerate(
                get_batches(sorted_summaries, sorted_texts, batch_size)):
            start_time = time.time()
            _, loss = sess.run(
                [train_op, cost],
                {input_data: texts_batch,
                 targets: summaries_batch,
                 lr: learning_rate,
                 summary_length: summaries_lengths,
                 text_length: texts_lengths,
                 keep_prob: keep_probability})

            batch_loss += loss
            update_loss += loss
            end_time = time.time()
            batch_time = end_time - start_time

            if batch_i % display_step == 0 and batch_i > 0:
                print('Epoch {:>3}/{} Batch {:>4}/{} - Loss: {:>6.3f}, Seconds: {:>4.2f}'
                      .format(epoch_i,
                              epochs, 
                              batch_i, 
                              len(sorted_texts) // batch_size, 
                              batch_loss / display_step, 
                              batch_time*display_step))
                batch_loss = 0
                
                #saver = tf.train.Saver() 
                #saver.save(sess, checkpoint)
                
            if batch_i % update_check == 0 and batch_i > 0:
                print("Average loss for this update:", round(update_loss/update_check,3))
                summary_update_loss.append(update_loss)
                
              
                  
                # If the update loss is at a new minimum, save the model
                if update_loss <= min(summary_update_loss):
                    print('New Record!') 
                    stop_early = 0
                    saver = tf.train.Saver() 
                    saver.save(sess, checkpoint)

                else:
                    print("No Improvement.")
                    stop_early += 1
                    if stop_early == stop:
                        break
                update_loss = 0
            
                    
        # Reduce learning rate, but not below its minimum value
        learning_rate *= learning_rate_decay
        if learning_rate < min_learning_rate:
            learning_rate = min_learning_rate
        
        if stop_early == stop:
            print("Stopping Training.")
            break
# Out:
# Epoch   1/100 Batch   20/6655 - Loss:  5.537, Seconds: 1.28
# Epoch   1/100 Batch   40/6655 - Loss:  2.555, Seconds: 1.25
# Epoch   1/100 Batch   60/6655 - Loss:  2.652, Seconds: 1.16
# Epoch   1/100 Batch   80/6655 - Loss:  2.483, Seconds: 1.22
# Epoch   1/100 Batch  100/6655 - Loss:  2.426, Seconds: 0.98
# Epoch   1/100 Batch  120/6655 - Loss:  2.333, Seconds: 1.38
# Epoch   1/100 Batch  140/6655 - Loss:  2.246, Seconds: 1.17
# Epoch   1/100 Batch  160/6655 - Loss:  2.252, Seconds: 1.33
# Epoch   1/100 Batch  180/6655 - Loss:  2.496, Seconds: 1.11
# Epoch   1/100 Batch  200/6655 - Loss:  2.241, Seconds: 1.38
# Epoch   1/100 Batch  220/6655 - Loss:  2.272, Seconds: 1.71
# Epoch   1/100 Batch  240/6655 - Loss:  2.092, Seconds: 1.47
# Epoch   1/100 Batch  260/6655 - Loss:  2.093, Seconds: 1.18
# Epoch   1/100 Batch  280/6655 - Loss:  2.251, Seconds: 1.04
# Epoch   1/100 Batch  300/6655 - Loss:  2.326, Seconds: 1.30
# Epoch   1/100 Batch  320/6655 - Loss:  2.210, Seconds: 1.35
# Epoch   1/100 Batch  340/6655 - Loss:  2.119, Seconds: 1.33
# Epoch   1/100 Batch  360/6655 - Loss:  2.218, Seconds: 1.29
# Epoch   1/100 Batch  380/6655 - Loss:  1.980, Seconds: 1.16
# Epoch   1/100 Batch  400/6655 - Loss:  2.093, Seconds: 1.21
# Epoch   1/100 Batch  420/6655 - Loss:  1.941, Seconds: 1.36
# Epoch   1/100 Batch  440/6655 - Loss:  2.369, Seconds: 1.27
# Epoch   1/100 Batch  460/6655 - Loss:  2.170, Seconds: 1.41
# Epoch   1/100 Batch  480/6655 - Loss:  2.273, Seconds: 1.47
# Epoch   1/100 Batch  500/6655 - Loss:  2.090, Seconds: 1.32
# Epoch   1/100 Batch  520/6655 - Loss:  1.983, Seconds: 1.33
# Epoch   1/100 Batch  540/6655 - Loss:  2.048, Seconds: 1.24
# Epoch   1/100 Batch  560/6655 - Loss:  1.965, Seconds: 1.15
# Epoch   1/100 Batch  580/6655 - Loss:  2.083, Seconds: 1.26
# Epoch   1/100 Batch  600/6655 - Loss:  1.905, Seconds: 1.18
# Epoch   1/100 Batch  620/6655 - Loss:  2.109, Seconds: 1.40
# Epoch   1/100 Batch  640/6655 - Loss:  2.125, Seconds: 1.29
# Epoch   1/100 Batch  660/6655 - Loss:  1.953, Seconds: 1.41
# Epoch   1/100 Batch  680/6655 - Loss:  1.872, Seconds: 1.44
# Epoch   1/100 Batch  700/6655 - Loss:  1.942, Seconds: 1.49
# Epoch   1/100 Batch  720/6655 - Loss:  1.875, Seconds: 1.60
# Epoch   1/100 Batch  740/6655 - Loss:  1.861, Seconds: 1.58
# Epoch   1/100 Batch  760/6655 - Loss:  1.835, Seconds: 1.10
# Epoch   1/100 Batch  780/6655 - Loss:  1.762, Seconds: 1.11
# Epoch   1/100 Batch  800/6655 - Loss:  1.694, Seconds: 1.35
# Epoch   1/100 Batch  820/6655 - Loss:  1.784, Seconds: 1.29
# Epoch   1/100 Batch  840/6655 - Loss:  2.001, Seconds: 1.44
# Epoch   1/100 Batch  860/6655 - Loss:  2.046, Seconds: 1.55
# Epoch   1/100 Batch  880/6655 - Loss:  2.160, Seconds: 1.26
# Epoch   1/100 Batch  900/6655 - Loss:  2.002, Seconds: 1.48
# Epoch   1/100 Batch  920/6655 - Loss:  2.006, Seconds: 1.46
# Epoch   1/100 Batch  940/6655 - Loss:  1.934, Seconds: 1.51
# Epoch   1/100 Batch  960/6655 - Loss:  1.758, Seconds: 1.56
# Epoch   1/100 Batch  980/6655 - Loss:  1.781, Seconds: 1.61
# Epoch   1/100 Batch 1000/6655 - Loss:  1.762, Seconds: 1.31
# Epoch   1/100 Batch 1020/6655 - Loss:  1.817, Seconds: 1.39
# Epoch   1/100 Batch 1040/6655 - Loss:  1.816, Seconds: 1.28
# Epoch   1/100 Batch 1060/6655 - Loss:  1.906, Seconds: 1.54
# Epoch   1/100 Batch 1080/6655 - Loss:  2.031, Seconds: 1.52
# Epoch   1/100 Batch 1100/6655 - Loss:  2.025, Seconds: 1.25
# Epoch   1/100 Batch 1120/6655 - Loss:  1.997, Seconds: 1.48
# Epoch   1/100 Batch 1140/6655 - Loss:  2.004, Seconds: 1.16
# Epoch   1/100 Batch 1160/6655 - Loss:  1.800, Seconds: 1.45
# Epoch   1/100 Batch 1180/6655 - Loss:  1.749, Seconds: 1.62
# Epoch   1/100 Batch 1200/6655 - Loss:  1.760, Seconds: 1.42
# Epoch   1/100 Batch 1220/6655 - Loss:  1.699, Seconds: 1.55
# Epoch   1/100 Batch 1240/6655 - Loss:  1.815, Seconds: 1.25
# Epoch   1/100 Batch 1260/6655 - Loss:  1.758, Seconds: 1.49
# Epoch   1/100 Batch 1280/6655 - Loss:  1.741, Seconds: 1.44
# Epoch   1/100 Batch 1300/6655 - Loss:  2.015, Seconds: 1.22
# Epoch   1/100 Batch 1320/6655 - Loss:  1.965, Seconds: 1.37
# Epoch   1/100 Batch 1340/6655 - Loss:  1.841, Seconds: 1.48
# Epoch   1/100 Batch 1360/6655 - Loss:  1.785, Seconds: 1.71
# Epoch   1/100 Batch 1380/6655 - Loss:  1.948, Seconds: 1.33
# Epoch   1/100 Batch 1400/6655 - Loss:  1.878, Seconds: 1.35
# Epoch   1/100 Batch 1420/6655 - Loss:  1.657, Seconds: 1.43
# Epoch   1/100 Batch 1440/6655 - Loss:  1.723, Seconds: 1.49
# Epoch   1/100 Batch 1460/6655 - Loss:  1.826, Seconds: 1.33
# Epoch   1/100 Batch 1480/6655 - Loss:  1.645, Seconds: 1.35
# Epoch   1/100 Batch 1500/6655 - Loss:  1.601, Seconds: 1.36
# Epoch   1/100 Batch 1520/6655 - Loss:  1.839, Seconds: 1.39
# Epoch   1/100 Batch 1540/6655 - Loss:  1.946, Seconds: 1.29
# Epoch   1/100 Batch 1560/6655 - Loss:  1.912, Seconds: 1.18
# Epoch   1/100 Batch 1580/6655 - Loss:  1.748, Seconds: 1.38
# Epoch   1/100 Batch 1600/6655 - Loss:  1.814, Seconds: 1.55
# Epoch   1/100 Batch 1620/6655 - Loss:  1.776, Seconds: 1.49
# Epoch   1/100 Batch 1640/6655 - Loss:  1.680, Seconds: 1.38
# Epoch   1/100 Batch 1660/6655 - Loss:  1.671, Seconds: 1.43
# Epoch   1/100 Batch 1680/6655 - Loss:  1.710, Seconds: 1.45
# Epoch   1/100 Batch 1700/6655 - Loss:  1.621, Seconds: 1.64
# Epoch   1/100 Batch 1720/6655 - Loss:  1.708, Seconds: 1.24
# Epoch   1/100 Batch 1740/6655 - Loss:  1.873, Seconds: 1.55
# Epoch   1/100 Batch 1760/6655 - Loss:  2.010, Seconds: 1.60
# Epoch   1/100 Batch 1780/6655 - Loss:  1.868, Seconds: 1.74
# Epoch   1/100 Batch 1800/6655 - Loss:  1.821, Seconds: 1.51
# Epoch   1/100 Batch 1820/6655 - Loss:  1.936, Seconds: 1.52
# Epoch   1/100 Batch 1840/6655 - Loss:  1.802, Seconds: 1.51
# Epoch   1/100 Batch 1860/6655 - Loss:  1.569, Seconds: 1.27
# Epoch   1/100 Batch 1880/6655 - Loss:  1.616, Seconds: 1.60
# Epoch   1/100 Batch 1900/6655 - Loss:  1.672, Seconds: 1.40
# Epoch   1/100 Batch 1920/6655 - Loss:  1.538, Seconds: 1.68
# Epoch   1/100 Batch 1940/6655 - Loss:  1.999, Seconds: 1.29
# Epoch   1/100 Batch 1960/6655 - Loss:  1.979, Seconds: 1.53
# Epoch   1/100 Batch 1980/6655 - Loss:  1.942, Seconds: 1.78
# Epoch   1/100 Batch 2000/6655 - Loss:  1.956, Seconds: 1.55
# Epoch   1/100 Batch 2020/6655 - Loss:  1.720, Seconds: 1.53
# Epoch   1/100 Batch 2040/6655 - Loss:  1.818, Seconds: 1.52
# Epoch   1/100 Batch 2060/6655 - Loss:  1.617, Seconds: 1.66
# Epoch   1/100 Batch 2080/6655 - Loss:  1.703, Seconds: 1.69
# Epoch   1/100 Batch 2100/6655 - Loss:  1.692, Seconds: 1.71
# Epoch   1/100 Batch 2120/6655 - Loss:  1.590, Seconds: 1.42
# Epoch   1/100 Batch 2140/6655 - Loss:  2.015, Seconds: 1.65
# Epoch   1/100 Batch 2160/6655 - Loss:  1.939, Seconds: 1.32
# Epoch   1/100 Batch 2180/6655 - Loss:  1.905, Seconds: 1.71
# Epoch   1/100 Batch 2200/6655 - Loss:  1.842, Seconds: 1.51
# Average loss for this update: 1.968
# New Record!
# Epoch   1/100 Batch 2220/6655 - Loss:  1.859, Seconds: 1.59
# Epoch   1/100 Batch 2240/6655 - Loss:  1.643, Seconds: 1.58
# Epoch   1/100 Batch 2260/6655 - Loss:  1.636, Seconds: 1.80
# Epoch   1/100 Batch 2280/6655 - Loss:  1.728, Seconds: 1.53
# Epoch   1/100 Batch 2300/6655 - Loss:  1.615, Seconds: 1.72
# Epoch   1/100 Batch 2320/6655 - Loss:  1.790, Seconds: 2.18
# Epoch   1/100 Batch 2340/6655 - Loss:  2.038, Seconds: 1.80
# Epoch   1/100 Batch 2360/6655 - Loss:  1.909, Seconds: 1.80
# Epoch   1/100 Batch 2380/6655 - Loss:  1.814, Seconds: 1.50
# Epoch   1/100 Batch 2400/6655 - Loss:  1.773, Seconds: 1.79
# Epoch   1/100 Batch 2420/6655 - Loss:  1.680, Seconds: 1.55
# Epoch   1/100 Batch 2440/6655 - Loss:  1.712, Seconds: 1.64
# Epoch   1/100 Batch 2460/6655 - Loss:  1.657, Seconds: 1.82
# Epoch   1/100 Batch 2480/6655 - Loss:  1.619, Seconds: 1.52
# Epoch   1/100 Batch 2500/6655 - Loss:  1.719, Seconds: 1.86
# Epoch   1/100 Batch 2520/6655 - Loss:  1.956, Seconds: 1.40
# Epoch   1/100 Batch 2540/6655 - Loss:  1.791, Seconds: 1.67
# Epoch   1/100 Batch 2560/6655 - Loss:  1.770, Seconds: 1.74
# Epoch   1/100 Batch 2580/6655 - Loss:  1.826, Seconds: 1.80
# Epoch   1/100 Batch 2600/6655 - Loss:  1.716, Seconds: 1.74
# Epoch   1/100 Batch 2620/6655 - Loss:  1.618, Seconds: 1.51
# Epoch   1/100 Batch 2640/6655 - Loss:  1.703, Seconds: 1.76
# Epoch   1/100 Batch 2660/6655 - Loss:  1.509, Seconds: 1.68
# Epoch   1/100 Batch 2680/6655 - Loss:  1.728, Seconds: 1.93
# Epoch   1/100 Batch 2700/6655 - Loss:  2.091, Seconds: 1.63
# Epoch   1/100 Batch 2720/6655 - Loss:  1.956, Seconds: 1.72
# Epoch   1/100 Batch 2740/6655 - Loss:  1.795, Seconds: 1.74
# Epoch   1/100 Batch 2760/6655 - Loss:  1.946, Seconds: 1.41
# Epoch   1/100 Batch 2780/6655 - Loss:  1.613, Seconds: 1.71
# Epoch   1/100 Batch 2800/6655 - Loss:  1.689, Seconds: 1.52
# Epoch   1/100 Batch 2820/6655 - Loss:  1.662, Seconds: 1.86
# Epoch   1/100 Batch 2840/6655 - Loss:  1.629, Seconds: 1.65
# Epoch   1/100 Batch 2860/6655 - Loss:  1.978, Seconds: 1.82
# Epoch   1/100 Batch 2880/6655 - Loss:  1.919, Seconds: 2.02
# Epoch   1/100 Batch 2900/6655 - Loss:  1.912, Seconds: 1.68
# Epoch   1/100 Batch 2920/6655 - Loss:  1.841, Seconds: 1.50
# Epoch   1/100 Batch 2940/6655 - Loss:  1.750, Seconds: 1.85
# Epoch   1/100 Batch 2960/6655 - Loss:  1.660, Seconds: 1.66
# Epoch   1/100 Batch 2980/6655 - Loss:  1.760, Seconds: 1.83
# Epoch   1/100 Batch 3000/6655 - Loss:  1.641, Seconds: 1.93
# Epoch   1/100 Batch 3020/6655 - Loss:  2.021, Seconds: 1.73
# Epoch   1/100 Batch 3040/6655 - Loss:  1.919, Seconds: 1.75
# Epoch   1/100 Batch 3060/6655 - Loss:  1.766, Seconds: 1.70
# Epoch   1/100 Batch 3080/6655 - Loss:  1.709, Seconds: 1.87
# Epoch   1/100 Batch 3100/6655 - Loss:  1.644, Seconds: 1.62
# Epoch   1/100 Batch 3120/6655 - Loss:  1.629, Seconds: 2.01
# Epoch   1/100 Batch 3140/6655 - Loss:  1.689, Seconds: 1.84
# Epoch   1/100 Batch 3160/6655 - Loss:  1.650, Seconds: 1.82
# Epoch   1/100 Batch 3180/6655 - Loss:  1.909, Seconds: 1.92
# Epoch   1/100 Batch 3200/6655 - Loss:  1.897, Seconds: 1.75
# Epoch   1/100 Batch 3220/6655 - Loss:  1.887, Seconds: 1.80
# Epoch   1/100 Batch 3240/6655 - Loss:  1.837, Seconds: 1.69
# Epoch   1/100 Batch 3260/6655 - Loss:  1.661, Seconds: 1.76
# Epoch   1/100 Batch 3280/6655 - Loss:  1.727, Seconds: 1.89
# Epoch   1/100 Batch 3300/6655 - Loss:  1.703, Seconds: 2.03
# Epoch   1/100 Batch 3320/6655 - Loss:  1.961, Seconds: 1.94
# Epoch   1/100 Batch 3340/6655 - Loss:  1.851, Seconds: 1.82
# Epoch   1/100 Batch 3360/6655 - Loss:  1.831, Seconds: 1.94
# Epoch   1/100 Batch 3380/6655 - Loss:  1.714, Seconds: 1.85
# Epoch   1/100 Batch 3400/6655 - Loss:  1.626, Seconds: 1.73
# Epoch   1/100 Batch 3420/6655 - Loss:  1.644, Seconds: 1.90
# Epoch   1/100 Batch 3440/6655 - Loss:  1.585, Seconds: 2.01
# Epoch   1/100 Batch 3460/6655 - Loss:  2.039, Seconds: 2.00
# Epoch   1/100 Batch 3480/6655 - Loss:  2.008, Seconds: 1.84
# Epoch   1/100 Batch 3500/6655 - Loss:  1.833, Seconds: 1.91
# Epoch   1/100 Batch 3520/6655 - Loss:  1.739, Seconds: 1.93
# Epoch   1/100 Batch 3540/6655 - Loss:  1.547, Seconds: 1.69
# Epoch   1/100 Batch 3560/6655 - Loss:  1.678, Seconds: 2.01
# Epoch   1/100 Batch 3580/6655 - Loss:  1.702, Seconds: 1.76
# Epoch   1/100 Batch 3600/6655 - Loss:  1.909, Seconds: 1.97
# Epoch   1/100 Batch 3620/6655 - Loss:  1.949, Seconds: 1.99
# Epoch   1/100 Batch 3640/6655 - Loss:  1.857, Seconds: 1.92
# Epoch   1/100 Batch 3660/6655 - Loss:  1.742, Seconds: 2.00
# Epoch   1/100 Batch 3680/6655 - Loss:  1.679, Seconds: 1.96
# Epoch   1/100 Batch 3700/6655 - Loss:  1.759, Seconds: 2.09
# Epoch   1/100 Batch 3720/6655 - Loss:  1.743, Seconds: 1.97
# Epoch   1/100 Batch 3740/6655 - Loss:  2.083, Seconds: 1.70
# Epoch   1/100 Batch 3760/6655 - Loss:  1.984, Seconds: 1.97
# Epoch   1/100 Batch 3780/6655 - Loss:  1.947, Seconds: 1.81
# Epoch   1/100 Batch 3800/6655 - Loss:  1.724, Seconds: 1.76
# Epoch   1/100 Batch 3820/6655 - Loss:  1.699, Seconds: 1.94
# Epoch   1/100 Batch 3840/6655 - Loss:  1.577, Seconds: 2.03
# Epoch   1/100 Batch 3860/6655 - Loss:  2.037, Seconds: 2.08
# Epoch   1/100 Batch 3880/6655 - Loss:  2.037, Seconds: 1.82
# Epoch   1/100 Batch 3900/6655 - Loss:  1.879, Seconds: 1.91
# Epoch   1/100 Batch 3920/6655 - Loss:  1.694, Seconds: 1.77
# Epoch   1/100 Batch 3940/6655 - Loss:  1.688, Seconds: 2.03
# Epoch   1/100 Batch 3960/6655 - Loss:  1.734, Seconds: 2.06
# Epoch   1/100 Batch 3980/6655 - Loss:  1.837, Seconds: 2.09
# Epoch   1/100 Batch 4000/6655 - Loss:  1.955, Seconds: 2.11
# Epoch   1/100 Batch 4020/6655 - Loss:  1.866, Seconds: 2.06
# Epoch   1/100 Batch 4040/6655 - Loss:  1.912, Seconds: 1.81
# Epoch   1/100 Batch 4060/6655 - Loss:  1.721, Seconds: 1.96
# Epoch   1/100 Batch 4080/6655 - Loss:  1.623, Seconds: 2.08
# Epoch   1/100 Batch 4100/6655 - Loss:  1.987, Seconds: 2.16
# Epoch   1/100 Batch 4120/6655 - Loss:  1.965, Seconds: 2.22
# Epoch   1/100 Batch 4140/6655 - Loss:  1.812, Seconds: 2.03
# Epoch   1/100 Batch 4160/6655 - Loss:  1.755, Seconds: 1.79
# Epoch   1/100 Batch 4180/6655 - Loss:  1.724, Seconds: 2.22
# Epoch   1/100 Batch 4200/6655 - Loss:  1.738, Seconds: 2.24
# Epoch   1/100 Batch 4220/6655 - Loss:  1.917, Seconds: 2.16
# Epoch   1/100 Batch 4240/6655 - Loss:  1.813, Seconds: 2.15
# Epoch   1/100 Batch 4260/6655 - Loss:  1.716, Seconds: 2.15
# Epoch   1/100 Batch 4280/6655 - Loss:  1.681, Seconds: 2.03
# Epoch   1/100 Batch 4300/6655 - Loss:  1.646, Seconds: 2.38
# Epoch   1/100 Batch 4320/6655 - Loss:  1.991, Seconds: 2.22
# Epoch   1/100 Batch 4340/6655 - Loss:  1.880, Seconds: 2.06
# Epoch   1/100 Batch 4360/6655 - Loss:  1.732, Seconds: 2.07
# Epoch   1/100 Batch 4380/6655 - Loss:  1.688, Seconds: 2.26
# Epoch   1/100 Batch 4400/6655 - Loss:  1.640, Seconds: 2.21
# Epoch   1/100 Batch 4420/6655 - Loss:  1.950, Seconds: 2.26
# Average loss for this update: 1.787
# New Record!
# Epoch   1/100 Batch 4440/6655 - Loss:  1.869, Seconds: 2.17
# Epoch   1/100 Batch 4460/6655 - Loss:  1.759, Seconds: 2.18
# Epoch   1/100 Batch 4480/6655 - Loss:  1.653, Seconds: 2.08
# Epoch   1/100 Batch 4500/6655 - Loss:  1.696, Seconds: 2.09
# Epoch   1/100 Batch 4520/6655 - Loss:  1.973, Seconds: 2.30
# Epoch   1/100 Batch 4540/6655 - Loss:  1.849, Seconds: 2.50
# Epoch   1/100 Batch 4560/6655 - Loss:  1.789, Seconds: 2.25
# Epoch   1/100 Batch 4580/6655 - Loss:  1.726, Seconds: 2.41
# Epoch   1/100 Batch 4600/6655 - Loss:  1.694, Seconds: 2.25
# Epoch   1/100 Batch 4620/6655 - Loss:  1.971, Seconds: 2.39
# Epoch   1/100 Batch 4640/6655 - Loss:  1.868, Seconds: 2.14
# Epoch   1/100 Batch 4660/6655 - Loss:  1.743, Seconds: 2.28
# Epoch   1/100 Batch 4680/6655 - Loss:  1.645, Seconds: 2.17
# Epoch   1/100 Batch 4700/6655 - Loss:  1.901, Seconds: 2.22
# Epoch   1/100 Batch 4720/6655 - Loss:  2.021, Seconds: 1.98
# Epoch   1/100 Batch 4740/6655 - Loss:  1.800, Seconds: 2.25
# Epoch   1/100 Batch 4760/6655 - Loss:  1.676, Seconds: 2.39
# Epoch   1/100 Batch 4780/6655 - Loss:  1.826, Seconds: 2.21
# Epoch   1/100 Batch 4800/6655 - Loss:  2.050, Seconds: 2.28
# Epoch   1/100 Batch 4820/6655 - Loss:  2.049, Seconds: 2.21
# Epoch   1/100 Batch 4840/6655 - Loss:  1.731, Seconds: 2.21
# Epoch   1/100 Batch 4860/6655 - Loss:  1.761, Seconds: 2.36
# Epoch   1/100 Batch 4880/6655 - Loss:  1.986, Seconds: 2.37
# Epoch   1/100 Batch 4900/6655 - Loss:  1.968, Seconds: 2.30
# Epoch   1/100 Batch 4920/6655 - Loss:  1.757, Seconds: 2.34
# Epoch   1/100 Batch 4940/6655 - Loss:  1.728, Seconds: 2.33
# Epoch   1/100 Batch 4960/6655 - Loss:  2.067, Seconds: 2.43
# Epoch   1/100 Batch 4980/6655 - Loss:  1.940, Seconds: 2.22
# Epoch   1/100 Batch 5000/6655 - Loss:  1.745, Seconds: 2.27
# Epoch   1/100 Batch 5020/6655 - Loss:  1.816, Seconds: 2.38
# Epoch   1/100 Batch 5040/6655 - Loss:  2.098, Seconds: 2.27
# Epoch   1/100 Batch 5060/6655 - Loss:  1.861, Seconds: 2.83
# Epoch   1/100 Batch 5080/6655 - Loss:  1.779, Seconds: 2.21
# Epoch   1/100 Batch 5100/6655 - Loss:  1.830, Seconds: 2.42
# Epoch   1/100 Batch 5120/6655 - Loss:  1.992, Seconds: 2.47
# Epoch   1/100 Batch 5140/6655 - Loss:  1.988, Seconds: 2.26
# Epoch   1/100 Batch 5160/6655 - Loss:  1.679, Seconds: 2.38
# Epoch   1/100 Batch 5180/6655 - Loss:  1.929, Seconds: 2.56
# Epoch   1/100 Batch 5200/6655 - Loss:  1.947, Seconds: 2.73
# Epoch   1/100 Batch 5220/6655 - Loss:  1.815, Seconds: 2.59
# Epoch   1/100 Batch 5240/6655 - Loss:  1.681, Seconds: 2.38
# Epoch   1/100 Batch 5260/6655 - Loss:  2.104, Seconds: 2.30
# Epoch   1/100 Batch 5280/6655 - Loss:  1.893, Seconds: 2.59
# Epoch   1/100 Batch 5300/6655 - Loss:  1.774, Seconds: 2.44
# Epoch   1/100 Batch 5320/6655 - Loss:  1.922, Seconds: 2.59
# Epoch   1/100 Batch 5340/6655 - Loss:  2.003, Seconds: 2.41
# Epoch   1/100 Batch 5360/6655 - Loss:  1.761, Seconds: 2.40
# Epoch   1/100 Batch 5380/6655 - Loss:  1.900, Seconds: 2.35
# Epoch   1/100 Batch 5400/6655 - Loss:  1.966, Seconds: 2.65
# Epoch   1/100 Batch 5420/6655 - Loss:  1.744, Seconds: 2.67
# Epoch   1/100 Batch 5440/6655 - Loss:  1.768, Seconds: 2.76
# Epoch   1/100 Batch 5460/6655 - Loss:  2.120, Seconds: 2.70
# Epoch   1/100 Batch 5480/6655 - Loss:  1.869, Seconds: 2.67
# Epoch   1/100 Batch 5500/6655 - Loss:  1.825, Seconds: 2.50
# Epoch   1/100 Batch 5520/6655 - Loss:  2.124, Seconds: 2.56
# Epoch   1/100 Batch 5540/6655 - Loss:  1.891, Seconds: 2.57
# Epoch   1/100 Batch 5560/6655 - Loss:  1.900, Seconds: 2.77
# Epoch   1/100 Batch 5580/6655 - Loss:  2.149, Seconds: 2.76
# Epoch   1/100 Batch 5600/6655 - Loss:  1.833, Seconds: 2.79
# Epoch   1/100 Batch 5620/6655 - Loss:  1.842, Seconds: 2.59
# Epoch   1/100 Batch 5640/6655 - Loss:  2.104, Seconds: 2.69
# Epoch   1/100 Batch 5660/6655 - Loss:  1.795, Seconds: 2.64
# Epoch   1/100 Batch 5680/6655 - Loss:  1.951, Seconds: 2.72
# Epoch   1/100 Batch 5700/6655 - Loss:  1.977, Seconds: 3.08
# Epoch   1/100 Batch 5720/6655 - Loss:  1.704, Seconds: 2.80
# Epoch   1/100 Batch 5740/6655 - Loss:  2.090, Seconds: 2.94
# Epoch   1/100 Batch 5760/6655 - Loss:  1.914, Seconds: 2.81
# Epoch   1/100 Batch 5780/6655 - Loss:  1.933, Seconds: 2.87
# Epoch   1/100 Batch 5800/6655 - Loss:  1.995, Seconds: 2.82
# Epoch   1/100 Batch 5820/6655 - Loss:  1.832, Seconds: 3.01
# Epoch   1/100 Batch 5840/6655 - Loss:  2.102, Seconds: 2.78
# Epoch   1/100 Batch 5860/6655 - Loss:  1.825, Seconds: 2.80
# Epoch   1/100 Batch 5880/6655 - Loss:  2.030, Seconds: 2.90
# Epoch   1/100 Batch 5900/6655 - Loss:  1.909, Seconds: 2.91
# Epoch   1/100 Batch 5920/6655 - Loss:  2.033, Seconds: 3.08
# Epoch   1/100 Batch 5940/6655 - Loss:  2.040, Seconds: 2.77
# Epoch   1/100 Batch 5960/6655 - Loss:  2.086, Seconds: 2.86
# Epoch   1/100 Batch 5980/6655 - Loss:  1.921, Seconds: 2.77
# Epoch   1/100 Batch 6000/6655 - Loss:  1.931, Seconds: 3.05
# Epoch   1/100 Batch 6020/6655 - Loss:  2.082, Seconds: 3.02
# Epoch   1/100 Batch 6040/6655 - Loss:  1.952, Seconds: 3.13
# Epoch   1/100 Batch 6060/6655 - Loss:  2.004, Seconds: 2.98
# Epoch   1/100 Batch 6080/6655 - Loss:  2.052, Seconds: 3.03
# Epoch   1/100 Batch 6100/6655 - Loss:  2.037, Seconds: 3.11
# Epoch   1/100 Batch 6120/6655 - Loss:  2.047, Seconds: 3.26
# Epoch   1/100 Batch 6140/6655 - Loss:  2.019, Seconds: 3.02
# Epoch   1/100 Batch 6160/6655 - Loss:  2.196, Seconds: 3.29
# Epoch   1/100 Batch 6180/6655 - Loss:  1.981, Seconds: 3.25
# Epoch   1/100 Batch 6200/6655 - Loss:  2.199, Seconds: 3.30
# Epoch   1/100 Batch 6220/6655 - Loss:  2.138, Seconds: 3.28
# Epoch   1/100 Batch 6240/6655 - Loss:  1.940, Seconds: 3.24
# Epoch   1/100 Batch 6260/6655 - Loss:  2.054, Seconds: 3.19
# Epoch   1/100 Batch 6280/6655 - Loss:  1.922, Seconds: 3.38
# Epoch   1/100 Batch 6300/6655 - Loss:  2.012, Seconds: 3.43
# Epoch   1/100 Batch 6320/6655 - Loss:  2.137, Seconds: 3.21
# Epoch   1/100 Batch 6340/6655 - Loss:  1.991, Seconds: 3.41
# Epoch   1/100 Batch 6360/6655 - Loss:  2.029, Seconds: 3.52
# Epoch   1/100 Batch 6380/6655 - Loss:  2.082, Seconds: 3.45
# Epoch   1/100 Batch 6400/6655 - Loss:  2.020, Seconds: 3.32
# Epoch   1/100 Batch 6420/6655 - Loss:  2.069, Seconds: 3.48
# Epoch   1/100 Batch 6440/6655 - Loss:  2.088, Seconds: 3.36
# Epoch   1/100 Batch 6460/6655 - Loss:  2.206, Seconds: 3.72
# Epoch   1/100 Batch 6480/6655 - Loss:  2.205, Seconds: 3.63
# Epoch   1/100 Batch 6500/6655 - Loss:  2.125, Seconds: 3.58
# Epoch   1/100 Batch 6520/6655 - Loss:  2.104, Seconds: 3.54
# Epoch   1/100 Batch 6540/6655 - Loss:  2.031, Seconds: 3.50
# Epoch   1/100 Batch 6560/6655 - Loss:  2.005, Seconds: 3.93
# Epoch   1/100 Batch 6580/6655 - Loss:  2.159, Seconds: 3.73
# Epoch   1/100 Batch 6600/6655 - Loss:  2.252, Seconds: 3.77
# Epoch   1/100 Batch 6620/6655 - Loss:  2.131, Seconds: 3.95
# Epoch   1/100 Batch 6640/6655 - Loss:  2.144, Seconds: 3.77
# Average loss for this update: 1.944
# No Improvement.
# Epoch   2/100 Batch   20/6655 - Loss:  2.931, Seconds: 1.41
# Epoch   2/100 Batch   40/6655 - Loss:  1.705, Seconds: 1.18
# Epoch   2/100 Batch   60/6655 - Loss:  1.796, Seconds: 1.12
# Epoch   2/100 Batch   80/6655 - Loss:  1.585, Seconds: 1.23
# Epoch   2/100 Batch  100/6655 - Loss:  1.673, Seconds: 0.99
# Epoch   2/100 Batch  120/6655 - Loss:  1.563, Seconds: 1.40
# Epoch   2/100 Batch  140/6655 - Loss:  1.605, Seconds: 1.15
# Epoch   2/100 Batch  160/6655 - Loss:  1.732, Seconds: 1.35
# Epoch   2/100 Batch  180/6655 - Loss:  1.931, Seconds: 1.11
# Epoch   2/100 Batch  200/6655 - Loss:  1.643, Seconds: 1.33
# Epoch   2/100 Batch  220/6655 - Loss:  1.630, Seconds: 1.41
# Epoch   2/100 Batch  240/6655 - Loss:  1.502, Seconds: 1.51
# Epoch   2/100 Batch  260/6655 - Loss:  1.487, Seconds: 1.20
# Epoch   2/100 Batch  280/6655 - Loss:  1.711, Seconds: 1.04
# Epoch   2/100 Batch  300/6655 - Loss:  1.812, Seconds: 1.27
# Epoch   2/100 Batch  320/6655 - Loss:  1.671, Seconds: 1.36
# Epoch   2/100 Batch  340/6655 - Loss:  1.588, Seconds: 1.29
# Epoch   2/100 Batch  360/6655 - Loss:  1.703, Seconds: 1.27
# Epoch   2/100 Batch  380/6655 - Loss:  1.494, Seconds: 1.14
# Epoch   2/100 Batch  400/6655 - Loss:  1.588, Seconds: 1.22
# Epoch   2/100 Batch  420/6655 - Loss:  1.459, Seconds: 1.34
# Epoch   2/100 Batch  440/6655 - Loss:  1.835, Seconds: 1.27
# Epoch   2/100 Batch  460/6655 - Loss:  1.689, Seconds: 1.36
# Epoch   2/100 Batch  480/6655 - Loss:  1.785, Seconds: 1.49
# Epoch   2/100 Batch  500/6655 - Loss:  1.639, Seconds: 1.35
# Epoch   2/100 Batch  520/6655 - Loss:  1.563, Seconds: 1.31
# Epoch   2/100 Batch  540/6655 - Loss:  1.586, Seconds: 1.22
# Epoch   2/100 Batch  560/6655 - Loss:  1.486, Seconds: 1.14
# Epoch   2/100 Batch  580/6655 - Loss:  1.631, Seconds: 1.26
# Epoch   2/100 Batch  600/6655 - Loss:  1.451, Seconds: 1.16
# Epoch   2/100 Batch  620/6655 - Loss:  1.684, Seconds: 1.42
# Epoch   2/100 Batch  640/6655 - Loss:  1.727, Seconds: 1.27
# Epoch   2/100 Batch  660/6655 - Loss:  1.580, Seconds: 1.45
# Epoch   2/100 Batch  680/6655 - Loss:  1.496, Seconds: 1.41
# Epoch   2/100 Batch  700/6655 - Loss:  1.579, Seconds: 1.54
# Epoch   2/100 Batch  720/6655 - Loss:  1.518, Seconds: 1.55
# Epoch   2/100 Batch  740/6655 - Loss:  1.516, Seconds: 1.54
# Epoch   2/100 Batch  760/6655 - Loss:  1.484, Seconds: 1.09
# Epoch   2/100 Batch  780/6655 - Loss:  1.433, Seconds: 1.10
# Epoch   2/100 Batch  800/6655 - Loss:  1.381, Seconds: 1.32
# Epoch   2/100 Batch  820/6655 - Loss:  1.430, Seconds: 1.24
# Epoch   2/100 Batch  840/6655 - Loss:  1.641, Seconds: 1.42
# Epoch   2/100 Batch  860/6655 - Loss:  1.699, Seconds: 1.51
# Epoch   2/100 Batch  880/6655 - Loss:  1.796, Seconds: 1.31
# Epoch   2/100 Batch  900/6655 - Loss:  1.658, Seconds: 1.42
# Epoch   2/100 Batch  920/6655 - Loss:  1.665, Seconds: 1.46
# Epoch   2/100 Batch  940/6655 - Loss:  1.587, Seconds: 1.77
# Epoch   2/100 Batch  960/6655 - Loss:  1.465, Seconds: 1.57
# Epoch   2/100 Batch  980/6655 - Loss:  1.476, Seconds: 1.59
# Epoch   2/100 Batch 1000/6655 - Loss:  1.452, Seconds: 1.28
# Epoch   2/100 Batch 1020/6655 - Loss:  1.517, Seconds: 1.36
# Epoch   2/100 Batch 1040/6655 - Loss:  1.517, Seconds: 1.33
# Epoch   2/100 Batch 1060/6655 - Loss:  1.589, Seconds: 1.58
# Epoch   2/100 Batch 1080/6655 - Loss:  1.704, Seconds: 1.45
# Epoch   2/100 Batch 1100/6655 - Loss:  1.688, Seconds: 1.26
# Epoch   2/100 Batch 1120/6655 - Loss:  1.690, Seconds: 1.61
# Epoch   2/100 Batch 1140/6655 - Loss:  1.679, Seconds: 1.18
# Epoch   2/100 Batch 1160/6655 - Loss:  1.524, Seconds: 1.33
# Epoch   2/100 Batch 1180/6655 - Loss:  1.476, Seconds: 1.57
# Epoch   2/100 Batch 1200/6655 - Loss:  1.480, Seconds: 1.37
# Epoch   2/100 Batch 1220/6655 - Loss:  1.427, Seconds: 1.68
# Epoch   2/100 Batch 1240/6655 - Loss:  1.546, Seconds: 1.23
# Epoch   2/100 Batch 1260/6655 - Loss:  1.486, Seconds: 1.51
# Epoch   2/100 Batch 1280/6655 - Loss:  1.467, Seconds: 1.44
# Epoch   2/100 Batch 1300/6655 - Loss:  1.720, Seconds: 1.19
# Epoch   2/100 Batch 1320/6655 - Loss:  1.673, Seconds: 1.39
# Epoch   2/100 Batch 1340/6655 - Loss:  1.594, Seconds: 1.53
# Epoch   2/100 Batch 1360/6655 - Loss:  1.517, Seconds: 1.71
# Epoch   2/100 Batch 1380/6655 - Loss:  1.665, Seconds: 1.35
# Epoch   2/100 Batch 1400/6655 - Loss:  1.619, Seconds: 1.35
# Epoch   2/100 Batch 1420/6655 - Loss:  1.443, Seconds: 1.44
# Epoch   2/100 Batch 1440/6655 - Loss:  1.492, Seconds: 1.50
# Epoch   2/100 Batch 1460/6655 - Loss:  1.570, Seconds: 1.38
# Epoch   2/100 Batch 1480/6655 - Loss:  1.428, Seconds: 1.32
# Epoch   2/100 Batch 1500/6655 - Loss:  1.377, Seconds: 1.38
# Epoch   2/100 Batch 1520/6655 - Loss:  1.593, Seconds: 1.39
# Epoch   2/100 Batch 1540/6655 - Loss:  1.692, Seconds: 1.31
# Epoch   2/100 Batch 1560/6655 - Loss:  1.663, Seconds: 1.12
# Epoch   2/100 Batch 1580/6655 - Loss:  1.506, Seconds: 1.37
# Epoch   2/100 Batch 1600/6655 - Loss:  1.593, Seconds: 1.51
# Epoch   2/100 Batch 1620/6655 - Loss:  1.541, Seconds: 1.44
# Epoch   2/100 Batch 1640/6655 - Loss:  1.471, Seconds: 1.40
# Epoch   2/100 Batch 1660/6655 - Loss:  1.451, Seconds: 1.43
# Epoch   2/100 Batch 1680/6655 - Loss:  1.498, Seconds: 1.46
# Epoch   2/100 Batch 1700/6655 - Loss:  1.409, Seconds: 1.57
# Epoch   2/100 Batch 1720/6655 - Loss:  1.494, Seconds: 1.25
# Epoch   2/100 Batch 1740/6655 - Loss:  1.619, Seconds: 1.55
# Epoch   2/100 Batch 1760/6655 - Loss:  1.756, Seconds: 1.62
# Epoch   2/100 Batch 1780/6655 - Loss:  1.621, Seconds: 1.71
# Epoch   2/100 Batch 1800/6655 - Loss:  1.582, Seconds: 1.45
# Epoch   2/100 Batch 1820/6655 - Loss:  1.691, Seconds: 1.51
# Epoch   2/100 Batch 1840/6655 - Loss:  1.567, Seconds: 1.49
# Epoch   2/100 Batch 1860/6655 - Loss:  1.381, Seconds: 1.25
# Epoch   2/100 Batch 1880/6655 - Loss:  1.417, Seconds: 1.54
# Epoch   2/100 Batch 1900/6655 - Loss:  1.456, Seconds: 1.40
# Epoch   2/100 Batch 1920/6655 - Loss:  1.371, Seconds: 1.70
# Epoch   2/100 Batch 1940/6655 - Loss:  1.749, Seconds: 1.28
# Epoch   2/100 Batch 1960/6655 - Loss:  1.723, Seconds: 1.56
# Epoch   2/100 Batch 1980/6655 - Loss:  1.703, Seconds: 1.77
# Epoch   2/100 Batch 2000/6655 - Loss:  1.718, Seconds: 1.51
# Epoch   2/100 Batch 2020/6655 - Loss:  1.509, Seconds: 1.49
# Epoch   2/100 Batch 2040/6655 - Loss:  1.607, Seconds: 1.50
# Epoch   2/100 Batch 2060/6655 - Loss:  1.414, Seconds: 1.71
# Epoch   2/100 Batch 2080/6655 - Loss:  1.518, Seconds: 1.68
# Epoch   2/100 Batch 2100/6655 - Loss:  1.492, Seconds: 1.75
# Epoch   2/100 Batch 2120/6655 - Loss:  1.430, Seconds: 1.41
# Epoch   2/100 Batch 2140/6655 - Loss:  1.755, Seconds: 1.63
# Epoch   2/100 Batch 2160/6655 - Loss:  1.712, Seconds: 1.31
# Epoch   2/100 Batch 2180/6655 - Loss:  1.685, Seconds: 1.72
# Epoch   2/100 Batch 2200/6655 - Loss:  1.630, Seconds: 1.51
# Average loss for this update: 1.597
# New Record!
# Epoch   2/100 Batch 2220/6655 - Loss:  1.652, Seconds: 1.63
# Epoch   2/100 Batch 2240/6655 - Loss:  1.460, Seconds: 1.57
# Epoch   2/100 Batch 2260/6655 - Loss:  1.452, Seconds: 1.77
# Epoch   2/100 Batch 2280/6655 - Loss:  1.542, Seconds: 1.47
# Epoch   2/100 Batch 2300/6655 - Loss:  1.438, Seconds: 1.71
# Epoch   2/100 Batch 2320/6655 - Loss:  1.589, Seconds: 2.23
# Epoch   2/100 Batch 2340/6655 - Loss:  1.808, Seconds: 1.83
# Epoch   2/100 Batch 2360/6655 - Loss:  1.691, Seconds: 1.90
# Epoch   2/100 Batch 2380/6655 - Loss:  1.606, Seconds: 1.63
# Epoch   2/100 Batch 2400/6655 - Loss:  1.587, Seconds: 1.78
# Epoch   2/100 Batch 2420/6655 - Loss:  1.483, Seconds: 1.71
# Epoch   2/100 Batch 2440/6655 - Loss:  1.528, Seconds: 1.73
# Epoch   2/100 Batch 2460/6655 - Loss:  1.484, Seconds: 2.02
# Epoch   2/100 Batch 2480/6655 - Loss:  1.455, Seconds: 1.53
# Epoch   2/100 Batch 2500/6655 - Loss:  1.538, Seconds: 1.82
# Epoch   2/100 Batch 2520/6655 - Loss:  1.731, Seconds: 1.35
# Epoch   2/100 Batch 2540/6655 - Loss:  1.593, Seconds: 1.76
# Epoch   2/100 Batch 2560/6655 - Loss:  1.581, Seconds: 1.59
# Epoch   2/100 Batch 2580/6655 - Loss:  1.637, Seconds: 1.88
# Epoch   2/100 Batch 2600/6655 - Loss:  1.534, Seconds: 1.78
# Epoch   2/100 Batch 2620/6655 - Loss:  1.456, Seconds: 1.45
# Epoch   2/100 Batch 2640/6655 - Loss:  1.527, Seconds: 1.77
# Epoch   2/100 Batch 2660/6655 - Loss:  1.378, Seconds: 1.64
# Epoch   2/100 Batch 2680/6655 - Loss:  1.557, Seconds: 1.71
# Epoch   2/100 Batch 2700/6655 - Loss:  1.861, Seconds: 1.65
# Epoch   2/100 Batch 2720/6655 - Loss:  1.746, Seconds: 1.70
# Epoch   2/100 Batch 2740/6655 - Loss:  1.581, Seconds: 1.66
# Epoch   2/100 Batch 2760/6655 - Loss:  1.733, Seconds: 1.41
# Epoch   2/100 Batch 2780/6655 - Loss:  1.438, Seconds: 1.70
# Epoch   2/100 Batch 2800/6655 - Loss:  1.521, Seconds: 1.49
# Epoch   2/100 Batch 2820/6655 - Loss:  1.491, Seconds: 1.87
# Epoch   2/100 Batch 2840/6655 - Loss:  1.477, Seconds: 1.63
# Epoch   2/100 Batch 2860/6655 - Loss:  1.762, Seconds: 1.85
# Epoch   2/100 Batch 2880/6655 - Loss:  1.711, Seconds: 1.90
# Epoch   2/100 Batch 2900/6655 - Loss:  1.706, Seconds: 1.60
# Epoch   2/100 Batch 2920/6655 - Loss:  1.665, Seconds: 1.55
# Epoch   2/100 Batch 2940/6655 - Loss:  1.583, Seconds: 1.93
# Epoch   2/100 Batch 2960/6655 - Loss:  1.510, Seconds: 1.66
# Epoch   2/100 Batch 2980/6655 - Loss:  1.593, Seconds: 1.83
# Epoch   2/100 Batch 3000/6655 - Loss:  1.486, Seconds: 2.02
# Epoch   2/100 Batch 3020/6655 - Loss:  1.808, Seconds: 1.69
# Epoch   2/100 Batch 3040/6655 - Loss:  1.729, Seconds: 1.79
# Epoch   2/100 Batch 3060/6655 - Loss:  1.584, Seconds: 1.72
# Epoch   2/100 Batch 3080/6655 - Loss:  1.550, Seconds: 1.87
# Epoch   2/100 Batch 3100/6655 - Loss:  1.503, Seconds: 1.63
# Epoch   2/100 Batch 3120/6655 - Loss:  1.487, Seconds: 1.82
# Epoch   2/100 Batch 3140/6655 - Loss:  1.524, Seconds: 1.85
# Epoch   2/100 Batch 3160/6655 - Loss:  1.485, Seconds: 1.82
# Epoch   2/100 Batch 3180/6655 - Loss:  1.706, Seconds: 1.90
# Epoch   2/100 Batch 3200/6655 - Loss:  1.712, Seconds: 1.88
# Epoch   2/100 Batch 3220/6655 - Loss:  1.701, Seconds: 1.84
# Epoch   2/100 Batch 3240/6655 - Loss:  1.652, Seconds: 1.67
# Epoch   2/100 Batch 3260/6655 - Loss:  1.514, Seconds: 1.76
# Epoch   2/100 Batch 3280/6655 - Loss:  1.580, Seconds: 1.94
# Epoch   2/100 Batch 3300/6655 - Loss:  1.554, Seconds: 2.00
# Epoch   2/100 Batch 3320/6655 - Loss:  1.759, Seconds: 2.06
# Epoch   2/100 Batch 3340/6655 - Loss:  1.676, Seconds: 1.87
# Epoch   2/100 Batch 3360/6655 - Loss:  1.645, Seconds: 1.91
# Epoch   2/100 Batch 3380/6655 - Loss:  1.566, Seconds: 1.86
# Epoch   2/100 Batch 3400/6655 - Loss:  1.462, Seconds: 1.68
# Epoch   2/100 Batch 3420/6655 - Loss:  1.501, Seconds: 1.81
# Epoch   2/100 Batch 3440/6655 - Loss:  1.452, Seconds: 2.19
# Epoch   2/100 Batch 3460/6655 - Loss:  1.838, Seconds: 2.00
# Epoch   2/100 Batch 3480/6655 - Loss:  1.809, Seconds: 1.74
# Epoch   2/100 Batch 3500/6655 - Loss:  1.651, Seconds: 1.83
# Epoch   2/100 Batch 3520/6655 - Loss:  1.575, Seconds: 1.97
# Epoch   2/100 Batch 3540/6655 - Loss:  1.420, Seconds: 1.68
# Epoch   2/100 Batch 3560/6655 - Loss:  1.524, Seconds: 1.98
# Epoch   2/100 Batch 3580/6655 - Loss:  1.558, Seconds: 1.88
# Epoch   2/100 Batch 3600/6655 - Loss:  1.720, Seconds: 1.97
# Epoch   2/100 Batch 3620/6655 - Loss:  1.763, Seconds: 1.96
# Epoch   2/100 Batch 3640/6655 - Loss:  1.667, Seconds: 1.93
# Epoch   2/100 Batch 3660/6655 - Loss:  1.585, Seconds: 1.96
# Epoch   2/100 Batch 3680/6655 - Loss:  1.535, Seconds: 2.02
# Epoch   2/100 Batch 3700/6655 - Loss:  1.597, Seconds: 1.92
# Epoch   2/100 Batch 3720/6655 - Loss:  1.598, Seconds: 1.89
# Epoch   2/100 Batch 3740/6655 - Loss:  1.874, Seconds: 1.66
# Epoch   2/100 Batch 3760/6655 - Loss:  1.769, Seconds: 1.98
# Epoch   2/100 Batch 3780/6655 - Loss:  1.768, Seconds: 1.78
# Epoch   2/100 Batch 3800/6655 - Loss:  1.559, Seconds: 1.80
# Epoch   2/100 Batch 3820/6655 - Loss:  1.537, Seconds: 1.95
# Epoch   2/100 Batch 3840/6655 - Loss:  1.451, Seconds: 1.97
# Epoch   2/100 Batch 3860/6655 - Loss:  1.830, Seconds: 1.90
# Epoch   2/100 Batch 3880/6655 - Loss:  1.836, Seconds: 1.86
# Epoch   2/100 Batch 3900/6655 - Loss:  1.695, Seconds: 1.92
# Epoch   2/100 Batch 3920/6655 - Loss:  1.551, Seconds: 1.85
# Epoch   2/100 Batch 3940/6655 - Loss:  1.544, Seconds: 1.94
# Epoch   2/100 Batch 3960/6655 - Loss:  1.583, Seconds: 1.94
# Epoch   2/100 Batch 3980/6655 - Loss:  1.667, Seconds: 2.04
# Epoch   2/100 Batch 4000/6655 - Loss:  1.786, Seconds: 2.08
# Epoch   2/100 Batch 4020/6655 - Loss:  1.692, Seconds: 2.09
# Epoch   2/100 Batch 4040/6655 - Loss:  1.736, Seconds: 1.92
# Epoch   2/100 Batch 4060/6655 - Loss:  1.575, Seconds: 1.98
# Epoch   2/100 Batch 4080/6655 - Loss:  1.482, Seconds: 2.09
# Epoch   2/100 Batch 4100/6655 - Loss:  1.795, Seconds: 2.19
# Epoch   2/100 Batch 4120/6655 - Loss:  1.751, Seconds: 2.20
# Epoch   2/100 Batch 4140/6655 - Loss:  1.640, Seconds: 2.04
# Epoch   2/100 Batch 4160/6655 - Loss:  1.600, Seconds: 1.81
# Epoch   2/100 Batch 4180/6655 - Loss:  1.551, Seconds: 2.19
# Epoch   2/100 Batch 4200/6655 - Loss:  1.587, Seconds: 2.20
# Epoch   2/100 Batch 4220/6655 - Loss:  1.736, Seconds: 2.11
# Epoch   2/100 Batch 4240/6655 - Loss:  1.637, Seconds: 2.11
# Epoch   2/100 Batch 4260/6655 - Loss:  1.559, Seconds: 2.10
# Epoch   2/100 Batch 4280/6655 - Loss:  1.552, Seconds: 2.08
# Epoch   2/100 Batch 4300/6655 - Loss:  1.507, Seconds: 2.18
# Epoch   2/100 Batch 4320/6655 - Loss:  1.811, Seconds: 2.14
# Epoch   2/100 Batch 4340/6655 - Loss:  1.707, Seconds: 2.06
# Epoch   2/100 Batch 4360/6655 - Loss:  1.592, Seconds: 2.10
# Epoch   2/100 Batch 4380/6655 - Loss:  1.560, Seconds: 2.24
# Epoch   2/100 Batch 4400/6655 - Loss:  1.508, Seconds: 2.13
# Epoch   2/100 Batch 4420/6655 - Loss:  1.777, Seconds: 2.27
# Average loss for this update: 1.613
# No Improvement.
# Epoch   2/100 Batch 4440/6655 - Loss:  1.723, Seconds: 2.15
# Epoch   2/100 Batch 4460/6655 - Loss:  1.610, Seconds: 2.18
# Epoch   2/100 Batch 4480/6655 - Loss:  1.511, Seconds: 2.11
# Epoch   2/100 Batch 4500/6655 - Loss:  1.556, Seconds: 2.15
# Epoch   2/100 Batch 4520/6655 - Loss:  1.797, Seconds: 2.15
# Epoch   2/100 Batch 4540/6655 - Loss:  1.680, Seconds: 2.19
# Epoch   2/100 Batch 4560/6655 - Loss:  1.619, Seconds: 2.26
# Epoch   2/100 Batch 4580/6655 - Loss:  1.577, Seconds: 2.23
# Epoch   2/100 Batch 4600/6655 - Loss:  1.545, Seconds: 2.13
# Epoch   2/100 Batch 4620/6655 - Loss:  1.804, Seconds: 2.10
# Epoch   2/100 Batch 4640/6655 - Loss:  1.701, Seconds: 2.17
# Epoch   2/100 Batch 4660/6655 - Loss:  1.602, Seconds: 2.24
# Epoch   2/100 Batch 4680/6655 - Loss:  1.555, Seconds: 2.17
# Epoch   2/100 Batch 4700/6655 - Loss:  1.770, Seconds: 2.18
# Epoch   2/100 Batch 4720/6655 - Loss:  1.838, Seconds: 1.97
# Epoch   2/100 Batch 4740/6655 - Loss:  1.660, Seconds: 2.28
# Epoch   2/100 Batch 4760/6655 - Loss:  1.559, Seconds: 2.32
# Epoch   2/100 Batch 4780/6655 - Loss:  1.686, Seconds: 2.19
# Epoch   2/100 Batch 4800/6655 - Loss:  1.856, Seconds: 2.40
# Epoch   2/100 Batch 4820/6655 - Loss:  1.863, Seconds: 2.25
# Epoch   2/100 Batch 4840/6655 - Loss:  1.590, Seconds: 2.26
# Epoch   2/100 Batch 4860/6655 - Loss:  1.632, Seconds: 2.29
# Epoch   2/100 Batch 4880/6655 - Loss:  1.813, Seconds: 2.47
# Epoch   2/100 Batch 4900/6655 - Loss:  1.801, Seconds: 2.39
# Epoch   2/100 Batch 4920/6655 - Loss:  1.621, Seconds: 2.53
# Epoch   2/100 Batch 4940/6655 - Loss:  1.596, Seconds: 2.32
# Epoch   2/100 Batch 4960/6655 - Loss:  1.870, Seconds: 2.44
# Epoch   2/100 Batch 4980/6655 - Loss:  1.792, Seconds: 2.47
# Epoch   2/100 Batch 5000/6655 - Loss:  1.613, Seconds: 2.19
# Epoch   2/100 Batch 5020/6655 - Loss:  1.679, Seconds: 2.42
# Epoch   2/100 Batch 5040/6655 - Loss:  1.909, Seconds: 2.28
# Epoch   2/100 Batch 5060/6655 - Loss:  1.691, Seconds: 2.50
# Epoch   2/100 Batch 5080/6655 - Loss:  1.623, Seconds: 2.21
# Epoch   2/100 Batch 5100/6655 - Loss:  1.687, Seconds: 2.55
# Epoch   2/100 Batch 5120/6655 - Loss:  1.816, Seconds: 2.37
# Epoch   2/100 Batch 5140/6655 - Loss:  1.812, Seconds: 2.33
# Epoch   2/100 Batch 5160/6655 - Loss:  1.553, Seconds: 2.29
# Epoch   2/100 Batch 5180/6655 - Loss:  1.778, Seconds: 2.56
# Epoch   2/100 Batch 5200/6655 - Loss:  1.786, Seconds: 2.68
# Epoch   2/100 Batch 5220/6655 - Loss:  1.660, Seconds: 2.49
# Epoch   2/100 Batch 5240/6655 - Loss:  1.565, Seconds: 2.46
# Epoch   2/100 Batch 5260/6655 - Loss:  1.917, Seconds: 2.41
# Epoch   2/100 Batch 5280/6655 - Loss:  1.724, Seconds: 2.57
# Epoch   2/100 Batch 5300/6655 - Loss:  1.633, Seconds: 2.42
# Epoch   2/100 Batch 5320/6655 - Loss:  1.771, Seconds: 2.65
# Epoch   2/100 Batch 5340/6655 - Loss:  1.827, Seconds: 2.50
# Epoch   2/100 Batch 5360/6655 - Loss:  1.616, Seconds: 2.47
# Epoch   2/100 Batch 5380/6655 - Loss:  1.760, Seconds: 2.61
# Epoch   2/100 Batch 5400/6655 - Loss:  1.799, Seconds: 2.61
# Epoch   2/100 Batch 5420/6655 - Loss:  1.622, Seconds: 2.68
# Epoch   2/100 Batch 5440/6655 - Loss:  1.635, Seconds: 2.62
# Epoch   2/100 Batch 5460/6655 - Loss:  1.934, Seconds: 2.69
# Epoch   2/100 Batch 5480/6655 - Loss:  1.709, Seconds: 2.61
# Epoch   2/100 Batch 5500/6655 - Loss:  1.683, Seconds: 2.47
# Epoch   2/100 Batch 5520/6655 - Loss:  1.915, Seconds: 2.60
# Epoch   2/100 Batch 5540/6655 - Loss:  1.731, Seconds: 2.54
# Epoch   2/100 Batch 5560/6655 - Loss:  1.749, Seconds: 2.79
# Epoch   2/100 Batch 5580/6655 - Loss:  1.950, Seconds: 2.65
# Epoch   2/100 Batch 5600/6655 - Loss:  1.677, Seconds: 2.78
# Epoch   2/100 Batch 5620/6655 - Loss:  1.700, Seconds: 2.75
# Epoch   2/100 Batch 5640/6655 - Loss:  1.922, Seconds: 2.56
# Epoch   2/100 Batch 5660/6655 - Loss:  1.648, Seconds: 2.62
# Epoch   2/100 Batch 5680/6655 - Loss:  1.785, Seconds: 2.67
# Epoch   2/100 Batch 5700/6655 - Loss:  1.793, Seconds: 2.89
# Epoch   2/100 Batch 5720/6655 - Loss:  1.571, Seconds: 2.76
# Epoch   2/100 Batch 5740/6655 - Loss:  1.902, Seconds: 2.86
# Epoch   2/100 Batch 5760/6655 - Loss:  1.748, Seconds: 2.91
# Epoch   2/100 Batch 5780/6655 - Loss:  1.770, Seconds: 3.02
# Epoch   2/100 Batch 5800/6655 - Loss:  1.812, Seconds: 2.75
# Epoch   2/100 Batch 5820/6655 - Loss:  1.660, Seconds: 2.92
# Epoch   2/100 Batch 5840/6655 - Loss:  1.918, Seconds: 2.72
# Epoch   2/100 Batch 5860/6655 - Loss:  1.673, Seconds: 2.86
# Epoch   2/100 Batch 5880/6655 - Loss:  1.868, Seconds: 3.15
# Epoch   2/100 Batch 5900/6655 - Loss:  1.769, Seconds: 3.01
# Epoch   2/100 Batch 5920/6655 - Loss:  1.865, Seconds: 3.24
# Epoch   2/100 Batch 5940/6655 - Loss:  1.886, Seconds: 2.88
# Epoch   2/100 Batch 5960/6655 - Loss:  1.893, Seconds: 2.92
# Epoch   2/100 Batch 5980/6655 - Loss:  1.746, Seconds: 2.88
# Epoch   2/100 Batch 6000/6655 - Loss:  1.774, Seconds: 3.11
# Epoch   2/100 Batch 6020/6655 - Loss:  1.908, Seconds: 2.79
# Epoch   2/100 Batch 6040/6655 - Loss:  1.798, Seconds: 3.17
# Epoch   2/100 Batch 6060/6655 - Loss:  1.821, Seconds: 3.03
# Epoch   2/100 Batch 6080/6655 - Loss:  1.873, Seconds: 3.08
# Epoch   2/100 Batch 6100/6655 - Loss:  1.848, Seconds: 2.96
# Epoch   2/100 Batch 6120/6655 - Loss:  1.900, Seconds: 3.19
# Epoch   2/100 Batch 6140/6655 - Loss:  1.846, Seconds: 3.31
# Epoch   2/100 Batch 6160/6655 - Loss:  2.024, Seconds: 3.34
# Epoch   2/100 Batch 6180/6655 - Loss:  1.816, Seconds: 3.27
# Epoch   2/100 Batch 6200/6655 - Loss:  2.008, Seconds: 3.18
# Epoch   2/100 Batch 6220/6655 - Loss:  1.972, Seconds: 3.25
# Epoch   2/100 Batch 6240/6655 - Loss:  1.784, Seconds: 3.26
# Epoch   2/100 Batch 6260/6655 - Loss:  1.882, Seconds: 3.42
# Epoch   2/100 Batch 6280/6655 - Loss:  1.760, Seconds: 3.55
# Epoch   2/100 Batch 6300/6655 - Loss:  1.853, Seconds: 3.32
# Epoch   2/100 Batch 6320/6655 - Loss:  1.973, Seconds: 3.15
# Epoch   2/100 Batch 6340/6655 - Loss:  1.828, Seconds: 3.45
# Epoch   2/100 Batch 6360/6655 - Loss:  1.846, Seconds: 3.53
# Epoch   2/100 Batch 6380/6655 - Loss:  1.919, Seconds: 3.51
# Epoch   2/100 Batch 6400/6655 - Loss:  1.869, Seconds: 3.26
# Epoch   2/100 Batch 6420/6655 - Loss:  1.909, Seconds: 3.41
# Epoch   2/100 Batch 6440/6655 - Loss:  1.900, Seconds: 3.34
# Epoch   2/100 Batch 6460/6655 - Loss:  2.037, Seconds: 3.58
# Epoch   2/100 Batch 6480/6655 - Loss:  2.015, Seconds: 3.75
# Epoch   2/100 Batch 6500/6655 - Loss:  1.958, Seconds: 3.43
# Epoch   2/100 Batch 6520/6655 - Loss:  1.942, Seconds: 3.74
# Epoch   2/100 Batch 6540/6655 - Loss:  1.861, Seconds: 3.54
# Epoch   2/100 Batch 6560/6655 - Loss:  1.838, Seconds: 3.78
# Epoch   2/100 Batch 6580/6655 - Loss:  1.988, Seconds: 3.64
# Epoch   2/100 Batch 6600/6655 - Loss:  2.051, Seconds: 3.69
# Epoch   2/100 Batch 6620/6655 - Loss:  1.954, Seconds: 3.92
# Epoch   2/100 Batch 6640/6655 - Loss:  1.983, Seconds: 3.86
# Average loss for this update: 1.782
# No Improvement.
# Epoch   3/100 Batch   20/6655 - Loss:  2.575, Seconds: 1.19
# Epoch   3/100 Batch   40/6655 - Loss:  1.582, Seconds: 1.18
# Epoch   3/100 Batch   60/6655 - Loss:  1.640, Seconds: 1.11
# Epoch   3/100 Batch   80/6655 - Loss:  1.450, Seconds: 1.21
# Epoch   3/100 Batch  100/6655 - Loss:  1.553, Seconds: 1.02
# Epoch   3/100 Batch  120/6655 - Loss:  1.444, Seconds: 1.40
# Epoch   3/100 Batch  140/6655 - Loss:  1.330, Seconds: 1.14
# Epoch   3/100 Batch  160/6655 - Loss:  1.413, Seconds: 1.33
# Epoch   3/100 Batch  180/6655 - Loss:  1.687, Seconds: 1.07
# Epoch   3/100 Batch  200/6655 - Loss:  1.436, Seconds: 1.31
# Epoch   3/100 Batch  220/6655 - Loss:  1.421, Seconds: 1.40
# Epoch   3/100 Batch  240/6655 - Loss:  1.328, Seconds: 1.49
# Epoch   3/100 Batch  260/6655 - Loss:  1.314, Seconds: 1.15
# Epoch   3/100 Batch  280/6655 - Loss:  1.524, Seconds: 1.04
# Epoch   3/100 Batch  300/6655 - Loss:  1.634, Seconds: 1.29
# Epoch   3/100 Batch  320/6655 - Loss:  1.513, Seconds: 1.37
# Epoch   3/100 Batch  340/6655 - Loss:  1.437, Seconds: 1.25
# Epoch   3/100 Batch  360/6655 - Loss:  1.516, Seconds: 1.29
# Epoch   3/100 Batch  380/6655 - Loss:  1.338, Seconds: 1.11
# Epoch   3/100 Batch  400/6655 - Loss:  1.441, Seconds: 1.19
# Epoch   3/100 Batch  420/6655 - Loss:  1.313, Seconds: 1.33
# Epoch   3/100 Batch  440/6655 - Loss:  1.684, Seconds: 1.21
# Epoch   3/100 Batch  460/6655 - Loss:  1.540, Seconds: 1.37
# Epoch   3/100 Batch  480/6655 - Loss:  1.618, Seconds: 1.66
# Epoch   3/100 Batch  500/6655 - Loss:  1.484, Seconds: 1.33
# Epoch   3/100 Batch  520/6655 - Loss:  1.424, Seconds: 1.28
# Epoch   3/100 Batch  540/6655 - Loss:  1.432, Seconds: 1.26
# Epoch   3/100 Batch  560/6655 - Loss:  1.337, Seconds: 1.12
# Epoch   3/100 Batch  580/6655 - Loss:  1.486, Seconds: 1.22
# Epoch   3/100 Batch  600/6655 - Loss:  1.319, Seconds: 1.16
# Epoch   3/100 Batch  620/6655 - Loss:  1.549, Seconds: 1.40
# Epoch   3/100 Batch  640/6655 - Loss:  1.606, Seconds: 1.27
# Epoch   3/100 Batch  660/6655 - Loss:  1.452, Seconds: 1.41
# Epoch   3/100 Batch  680/6655 - Loss:  1.371, Seconds: 1.39
# Epoch   3/100 Batch  700/6655 - Loss:  1.450, Seconds: 1.52
# Epoch   3/100 Batch  720/6655 - Loss:  1.413, Seconds: 1.58
# Epoch   3/100 Batch  740/6655 - Loss:  1.387, Seconds: 1.30
# Epoch   3/100 Batch  760/6655 - Loss:  1.342, Seconds: 1.10
# Epoch   3/100 Batch  780/6655 - Loss:  1.320, Seconds: 1.08
# Epoch   3/100 Batch  800/6655 - Loss:  1.258, Seconds: 1.37
# Epoch   3/100 Batch  820/6655 - Loss:  1.304, Seconds: 1.25
# Epoch   3/100 Batch  840/6655 - Loss:  1.534, Seconds: 1.43
# Epoch   3/100 Batch  860/6655 - Loss:  1.596, Seconds: 1.51
# Epoch   3/100 Batch  880/6655 - Loss:  1.666, Seconds: 1.32
# Epoch   3/100 Batch  900/6655 - Loss:  1.533, Seconds: 1.47
# Epoch   3/100 Batch  920/6655 - Loss:  1.534, Seconds: 1.44
# Epoch   3/100 Batch  940/6655 - Loss:  1.466, Seconds: 1.51
# Epoch   3/100 Batch  960/6655 - Loss:  1.330, Seconds: 1.53
# Epoch   3/100 Batch  980/6655 - Loss:  1.348, Seconds: 1.61
# Epoch   3/100 Batch 1000/6655 - Loss:  1.346, Seconds: 1.35
# Epoch   3/100 Batch 1020/6655 - Loss:  1.395, Seconds: 1.38
# Epoch   3/100 Batch 1040/6655 - Loss:  1.408, Seconds: 1.33
# Epoch   3/100 Batch 1060/6655 - Loss:  1.493, Seconds: 1.68
# Epoch   3/100 Batch 1080/6655 - Loss:  1.600, Seconds: 1.47
# Epoch   3/100 Batch 1100/6655 - Loss:  1.586, Seconds: 1.24
# Epoch   3/100 Batch 1120/6655 - Loss:  1.582, Seconds: 1.50
# Epoch   3/100 Batch 1140/6655 - Loss:  1.574, Seconds: 1.14
# Epoch   3/100 Batch 1160/6655 - Loss:  1.418, Seconds: 1.33
# Epoch   3/100 Batch 1180/6655 - Loss:  1.352, Seconds: 1.60
# Epoch   3/100 Batch 1200/6655 - Loss:  1.352, Seconds: 1.39
# Epoch   3/100 Batch 1220/6655 - Loss:  1.330, Seconds: 1.56
# Epoch   3/100 Batch 1240/6655 - Loss:  1.428, Seconds: 1.24
# Epoch   3/100 Batch 1260/6655 - Loss:  1.368, Seconds: 1.48
# Epoch   3/100 Batch 1280/6655 - Loss:  1.355, Seconds: 1.41
# Epoch   3/100 Batch 1300/6655 - Loss:  1.625, Seconds: 1.18
# Epoch   3/100 Batch 1320/6655 - Loss:  1.557, Seconds: 1.33
# Epoch   3/100 Batch 1340/6655 - Loss:  1.484, Seconds: 1.51
# Epoch   3/100 Batch 1360/6655 - Loss:  1.414, Seconds: 1.64
# Epoch   3/100 Batch 1380/6655 - Loss:  1.547, Seconds: 1.25
# Epoch   3/100 Batch 1400/6655 - Loss:  1.498, Seconds: 1.36
# Epoch   3/100 Batch 1420/6655 - Loss:  1.333, Seconds: 1.45
# Epoch   3/100 Batch 1440/6655 - Loss:  1.387, Seconds: 1.49
# Epoch   3/100 Batch 1460/6655 - Loss:  1.453, Seconds: 1.36
# Epoch   3/100 Batch 1480/6655 - Loss:  1.322, Seconds: 1.35
# Epoch   3/100 Batch 1500/6655 - Loss:  1.286, Seconds: 1.33
# Epoch   3/100 Batch 1520/6655 - Loss:  1.501, Seconds: 1.38
# Epoch   3/100 Batch 1540/6655 - Loss:  1.606, Seconds: 1.32
# Epoch   3/100 Batch 1560/6655 - Loss:  1.562, Seconds: 1.10
# Epoch   3/100 Batch 1580/6655 - Loss:  1.416, Seconds: 1.44
# Epoch   3/100 Batch 1600/6655 - Loss:  1.495, Seconds: 1.53
# Epoch   3/100 Batch 1620/6655 - Loss:  1.452, Seconds: 1.44
# Epoch   3/100 Batch 1640/6655 - Loss:  1.360, Seconds: 1.39
# Epoch   3/100 Batch 1660/6655 - Loss:  1.365, Seconds: 1.45
# Epoch   3/100 Batch 1680/6655 - Loss:  1.402, Seconds: 1.43
# Epoch   3/100 Batch 1700/6655 - Loss:  1.327, Seconds: 1.61
# Epoch   3/100 Batch 1720/6655 - Loss:  1.394, Seconds: 1.23
# Epoch   3/100 Batch 1740/6655 - Loss:  1.528, Seconds: 1.58
# Epoch   3/100 Batch 1760/6655 - Loss:  1.665, Seconds: 1.57
# Epoch   3/100 Batch 1780/6655 - Loss:  1.531, Seconds: 1.74
# Epoch   3/100 Batch 1800/6655 - Loss:  1.490, Seconds: 1.48
# Epoch   3/100 Batch 1820/6655 - Loss:  1.568, Seconds: 1.50
# Epoch   3/100 Batch 1840/6655 - Loss:  1.463, Seconds: 1.52
# Epoch   3/100 Batch 1860/6655 - Loss:  1.283, Seconds: 1.21
# Epoch   3/100 Batch 1880/6655 - Loss:  1.320, Seconds: 1.58
# Epoch   3/100 Batch 1900/6655 - Loss:  1.371, Seconds: 1.40
# Epoch   3/100 Batch 1920/6655 - Loss:  1.283, Seconds: 1.66
# Epoch   3/100 Batch 1940/6655 - Loss:  1.642, Seconds: 1.43
# Epoch   3/100 Batch 1960/6655 - Loss:  1.629, Seconds: 1.52
# Epoch   3/100 Batch 1980/6655 - Loss:  1.596, Seconds: 1.95
# Epoch   3/100 Batch 2000/6655 - Loss:  1.623, Seconds: 1.54
# Epoch   3/100 Batch 2020/6655 - Loss:  1.424, Seconds: 1.49
# Epoch   3/100 Batch 2040/6655 - Loss:  1.485, Seconds: 1.50
# Epoch   3/100 Batch 2060/6655 - Loss:  1.321, Seconds: 1.67
# Epoch   3/100 Batch 2080/6655 - Loss:  1.417, Seconds: 1.65
# Epoch   3/100 Batch 2100/6655 - Loss:  1.407, Seconds: 1.67
# Epoch   3/100 Batch 2120/6655 - Loss:  1.328, Seconds: 1.45
# Epoch   3/100 Batch 2140/6655 - Loss:  1.665, Seconds: 1.61
# Epoch   3/100 Batch 2160/6655 - Loss:  1.635, Seconds: 1.38
# Epoch   3/100 Batch 2180/6655 - Loss:  1.600, Seconds: 1.72
# Epoch   3/100 Batch 2200/6655 - Loss:  1.528, Seconds: 1.53
# Average loss for this update: 1.472
# New Record!
# Epoch   3/100 Batch 2220/6655 - Loss:  1.557, Seconds: 1.89
# Epoch   3/100 Batch 2240/6655 - Loss:  1.373, Seconds: 1.56
# Epoch   3/100 Batch 2260/6655 - Loss:  1.369, Seconds: 1.80
# Epoch   3/100 Batch 2280/6655 - Loss:  1.454, Seconds: 1.63
# Epoch   3/100 Batch 2300/6655 - Loss:  1.352, Seconds: 1.70
# Epoch   3/100 Batch 2320/6655 - Loss:  1.512, Seconds: 1.74
# Epoch   3/100 Batch 2340/6655 - Loss:  1.710, Seconds: 1.80
# Epoch   3/100 Batch 2360/6655 - Loss:  1.592, Seconds: 1.92
# Epoch   3/100 Batch 2380/6655 - Loss:  1.508, Seconds: 1.64
# Epoch   3/100 Batch 2400/6655 - Loss:  1.508, Seconds: 1.83
# Epoch   3/100 Batch 2420/6655 - Loss:  1.391, Seconds: 1.59
# Epoch   3/100 Batch 2440/6655 - Loss:  1.429, Seconds: 1.69
# Epoch   3/100 Batch 2460/6655 - Loss:  1.397, Seconds: 1.90
# Epoch   3/100 Batch 2480/6655 - Loss:  1.374, Seconds: 1.50
# Epoch   3/100 Batch 2500/6655 - Loss:  1.449, Seconds: 1.86
# Epoch   3/100 Batch 2520/6655 - Loss:  1.636, Seconds: 1.37
# Epoch   3/100 Batch 2540/6655 - Loss:  1.517, Seconds: 1.69
# Epoch   3/100 Batch 2560/6655 - Loss:  1.493, Seconds: 1.62
# Epoch   3/100 Batch 2580/6655 - Loss:  1.546, Seconds: 1.77
# Epoch   3/100 Batch 2600/6655 - Loss:  1.455, Seconds: 1.80
# ...
# Epoch   5/100 Batch 3600/6655 - Loss:  2.795, Seconds: 1.98
# Epoch   5/100 Batch 3620/6655 - Loss:  2.974, Seconds: 1.94
# Epoch   5/100 Batch 3640/6655 - Loss:  2.906, Seconds: 1.96
# Epoch   5/100 Batch 3660/6655 - Loss:  2.778, Seconds: 1.99
# Epoch   5/100 Batch 3680/6655 - Loss:  2.835, Seconds: 1.96
# Epoch   5/100 Batch 3700/6655 - Loss:  2.833, Seconds: 1.92
# Epoch   5/100 Batch 3720/6655 - Loss:  2.841, Seconds: 1.89
# Epoch   5/100 Batch 3740/6655 - Loss:  3.026, Seconds: 1.71
# Epoch   5/100 Batch 3760/6655 - Loss:  2.928, Seconds: 2.02
# Epoch   5/100 Batch 3780/6655 - Loss:  3.026, Seconds: 1.82
# Epoch   5/100 Batch 3800/6655 - Loss:  2.786, Seconds: 1.76
# Epoch   5/100 Batch 3820/6655 - Loss:  2.774, Seconds: 1.94
# Epoch   5/100 Batch 3840/6655 - Loss:  2.660, Seconds: 2.03
# Epoch   5/100 Batch 3860/6655 - Loss:  2.975, Seconds: 1.90
# Epoch   5/100 Batch 3880/6655 - Loss:  2.943, Seconds: 1.82
# Epoch   5/100 Batch 3900/6655 - Loss:  2.883, Seconds: 1.88
# Epoch   5/100 Batch 3920/6655 - Loss:  2.708, Seconds: 1.77
# Epoch   5/100 Batch 3940/6655 - Loss:  2.676, Seconds: 1.99
# Epoch   5/100 Batch 3960/6655 - Loss:  2.725, Seconds: 1.94
# Epoch   5/100 Batch 3980/6655 - Loss:  2.692, Seconds: 2.06
# Epoch   5/100 Batch 4000/6655 - Loss:  2.840, Seconds: 2.03
# Epoch   5/100 Batch 4020/6655 - Loss:  2.743, Seconds: 2.12
# Epoch   5/100 Batch 4040/6655 - Loss:  2.830, Seconds: 1.79
# Epoch   5/100 Batch 4060/6655 - Loss:  2.721, Seconds: 2.00
# Epoch   5/100 Batch 4080/6655 - Loss:  2.555, Seconds: 2.05
# Epoch   5/100 Batch 4100/6655 - Loss:  2.823, Seconds: 2.18
# Epoch   5/100 Batch 4120/6655 - Loss:  2.868, Seconds: 2.25
# Epoch   5/100 Batch 4140/6655 - Loss:  2.727, Seconds: 2.02
# Epoch   5/100 Batch 4160/6655 - Loss:  2.722, Seconds: 1.80
# Epoch   5/100 Batch 4180/6655 - Loss:  2.687, Seconds: 2.13
# Epoch   5/100 Batch 4200/6655 - Loss:  2.707, Seconds: 2.20
# Epoch   5/100 Batch 4220/6655 - Loss:  2.724, Seconds: 2.14
# Epoch   5/100 Batch 4240/6655 - Loss:  2.684, Seconds: 2.12
# Epoch   5/100 Batch 4260/6655 - Loss:  2.593, Seconds: 2.12
# Epoch   5/100 Batch 4280/6655 - Loss:  2.596, Seconds: 2.10
# Epoch   5/100 Batch 4300/6655 - Loss:  2.569, Seconds: 2.20
# Epoch   5/100 Batch 4320/6655 - Loss:  2.756, Seconds: 2.12
# Epoch   5/100 Batch 4340/6655 - Loss:  2.658, Seconds: 2.19
# Epoch   5/100 Batch 4360/6655 - Loss:  2.581, Seconds: 2.03
# Epoch   5/100 Batch 4380/6655 - Loss:  2.593, Seconds: 2.31
# Epoch   5/100 Batch 4400/6655 - Loss:  2.541, Seconds: 2.12
# Epoch   5/100 Batch 4420/6655 - Loss:  2.666, Seconds: 2.30
# Average loss for this update: 2.881
# No Improvement.
# Epoch   5/100 Batch 4440/6655 - Loss:  2.638, Seconds: 2.24
# Epoch   5/100 Batch 4460/6655 - Loss:  2.617, Seconds: 2.16
# Epoch   5/100 Batch 4480/6655 - Loss:  2.541, Seconds: 2.14
# Epoch   5/100 Batch 4500/6655 - Loss:  2.580, Seconds: 2.20
# Epoch   5/100 Batch 4520/6655 - Loss:  2.728, Seconds: 2.14
# Epoch   5/100 Batch 4540/6655 - Loss:  2.620, Seconds: 2.17
# Epoch   5/100 Batch 4560/6655 - Loss:  2.876, Seconds: 2.25
# Epoch   5/100 Batch 4580/6655 - Loss:  3.650, Seconds: 2.26
# Epoch   5/100 Batch 4600/6655 - Loss:  3.259, Seconds: 2.38
# Epoch   5/100 Batch 4620/6655 - Loss:  3.266, Seconds: 2.15
# Epoch   5/100 Batch 4640/6655 - Loss:  3.137, Seconds: 2.18
# Epoch   5/100 Batch 4660/6655 - Loss:  3.007, Seconds: 2.27
# Epoch   5/100 Batch 4680/6655 - Loss:  2.846, Seconds: 2.29
# Epoch   5/100 Batch 4700/6655 - Loss:  3.045, Seconds: 2.57
# Epoch   5/100 Batch 4720/6655 - Loss:  3.131, Seconds: 1.93
# Epoch   5/100 Batch 4740/6655 - Loss:  2.925, Seconds: 2.25
# Epoch   5/100 Batch 4760/6655 - Loss:  2.814, Seconds: 2.18
# Epoch   5/100 Batch 4780/6655 - Loss:  2.994, Seconds: 2.45
# Epoch   5/100 Batch 4800/6655 - Loss:  3.142, Seconds: 2.29
# Epoch   5/100 Batch 4820/6655 - Loss:  3.217, Seconds: 2.21
# Epoch   5/100 Batch 4840/6655 - Loss:  2.885, Seconds: 2.21
# Epoch   5/100 Batch 4860/6655 - Loss:  2.890, Seconds: 2.53
# Epoch   5/100 Batch 4880/6655 - Loss:  2.888, Seconds: 2.41
# Epoch   5/100 Batch 4900/6655 - Loss:  2.921, Seconds: 2.44
# Epoch   5/100 Batch 4920/6655 - Loss:  2.811, Seconds: 2.43
# Epoch   5/100 Batch 4940/6655 - Loss:  2.742, Seconds: 2.29
# Epoch   5/100 Batch 4960/6655 - Loss:  2.952, Seconds: 2.45
# Epoch   5/100 Batch 4980/6655 - Loss:  2.845, Seconds: 2.31
# Epoch   5/100 Batch 5000/6655 - Loss:  2.767, Seconds: 2.28
# Epoch   5/100 Batch 5020/6655 - Loss:  2.842, Seconds: 2.38
# Epoch   5/100 Batch 5040/6655 - Loss:  2.908, Seconds: 2.31
# Epoch   5/100 Batch 5060/6655 - Loss:  2.672, Seconds: 2.66
# Epoch   5/100 Batch 5080/6655 - Loss:  2.739, Seconds: 2.26
# Epoch   5/100 Batch 5100/6655 - Loss:  2.775, Seconds: 2.26
# Epoch   5/100 Batch 5120/6655 - Loss:  2.748, Seconds: 2.49
# Epoch   5/100 Batch 5140/6655 - Loss:  2.853, Seconds: 2.32
# Epoch   5/100 Batch 5160/6655 - Loss:  2.701, Seconds: 2.34
# Epoch   5/100 Batch 5180/6655 - Loss:  2.833, Seconds: 2.58
# Epoch   5/100 Batch 5200/6655 - Loss:  2.719, Seconds: 2.60
# Epoch   5/100 Batch 5220/6655 - Loss:  2.734, Seconds: 2.56
# Epoch   5/100 Batch 5240/6655 - Loss:  2.627, Seconds: 2.49
# Epoch   5/100 Batch 5260/6655 - Loss:  2.912, Seconds: 2.48
# Epoch   5/100 Batch 5280/6655 - Loss:  2.669, Seconds: 2.65
# Epoch   5/100 Batch 5300/6655 - Loss:  2.689, Seconds: 2.42
# Epoch   5/100 Batch 5320/6655 - Loss:  2.734, Seconds: 2.67
# Epoch   5/100 Batch 5340/6655 - Loss:  2.793, Seconds: 2.36
# Epoch   5/100 Batch 5360/6655 - Loss:  2.625, Seconds: 2.50
# Epoch   5/100 Batch 5380/6655 - Loss:  2.784, Seconds: 2.43
# Epoch   5/100 Batch 5400/6655 - Loss:  2.698, Seconds: 2.63
# Epoch   5/100 Batch 5420/6655 - Loss:  2.538, Seconds: 2.74
# Epoch   5/100 Batch 5440/6655 - Loss:  2.560, Seconds: 2.63
# Epoch   5/100 Batch 5460/6655 - Loss:  2.861, Seconds: 2.75
# Epoch   5/100 Batch 5480/6655 - Loss:  2.726, Seconds: 2.77
# Epoch   5/100 Batch 5500/6655 - Loss:  2.694, Seconds: 2.49
# Epoch   5/100 Batch 5520/6655 - Loss:  2.866, Seconds: 2.52
# Epoch   5/100 Batch 5540/6655 - Loss:  2.802, Seconds: 2.64
# Epoch   5/100 Batch 5560/6655 - Loss:  2.836, Seconds: 2.84
# Epoch   5/100 Batch 5580/6655 - Loss:  2.901, Seconds: 2.63
# Epoch   5/100 Batch 5600/6655 - Loss:  2.653, Seconds: 2.83
# Epoch   5/100 Batch 5620/6655 - Loss:  2.670, Seconds: 2.68
# Epoch   5/100 Batch 5640/6655 - Loss:  2.802, Seconds: 2.59
# Epoch   5/100 Batch 5660/6655 - Loss:  2.580, Seconds: 2.57
# Epoch   5/100 Batch 5680/6655 - Loss:  2.692, Seconds: 2.75
# Epoch   5/100 Batch 5700/6655 - Loss:  2.661, Seconds: 2.77
# Epoch   5/100 Batch 5720/6655 - Loss:  2.527, Seconds: 2.80
# Epoch   5/100 Batch 5740/6655 - Loss:  2.778, Seconds: 2.87
# Epoch   5/100 Batch 5760/6655 - Loss:  2.681, Seconds: 2.99
# Epoch   5/100 Batch 5780/6655 - Loss:  2.681, Seconds: 2.94
# Epoch   5/100 Batch 5800/6655 - Loss:  2.667, Seconds: 2.64
# Epoch   5/100 Batch 5820/6655 - Loss:  2.595, Seconds: 2.92
# Epoch   5/100 Batch 5840/6655 - Loss:  2.792, Seconds: 2.93
# Epoch   5/100 Batch 5860/6655 - Loss:  2.662, Seconds: 2.83
# Epoch   5/100 Batch 5880/6655 - Loss:  2.767, Seconds: 3.02
# Epoch   5/100 Batch 5900/6655 - Loss:  2.697, Seconds: 2.96
# Epoch   5/100 Batch 5920/6655 - Loss:  2.739, Seconds: 3.02
# Epoch   5/100 Batch 5940/6655 - Loss:  2.797, Seconds: 2.84
# Epoch   5/100 Batch 5960/6655 - Loss:  2.764, Seconds: 2.92
# Epoch   5/100 Batch 5980/6655 - Loss:  2.594, Seconds: 2.80
# Epoch   5/100 Batch 6000/6655 - Loss:  2.655, Seconds: 3.09
# Epoch   5/100 Batch 6020/6655 - Loss:  2.790, Seconds: 2.92
# Epoch   5/100 Batch 6040/6655 - Loss:  2.633, Seconds: 3.17
# Epoch   5/100 Batch 6060/6655 - Loss:  2.701, Seconds: 2.92
# Epoch   5/100 Batch 6080/6655 - Loss:  2.837, Seconds: 3.14
# Epoch   5/100 Batch 6100/6655 - Loss:  2.763, Seconds: 3.30
# Epoch   5/100 Batch 6120/6655 - Loss:  2.793, Seconds: 3.13
# Epoch   5/100 Batch 6140/6655 - Loss:  2.681, Seconds: 3.08
# Epoch   5/100 Batch 6160/6655 - Loss:  3.197, Seconds: 3.20
# Epoch   5/100 Batch 6180/6655 - Loss: 89.136, Seconds: 3.27
# Epoch   5/100 Batch 6200/6655 - Loss: 77.853, Seconds: 3.12
# Epoch   5/100 Batch 6220/6655 - Loss: 78.651, Seconds: 3.32
# Epoch   5/100 Batch 6240/6655 - Loss: 71.904, Seconds: 3.51
# Epoch   5/100 Batch 6260/6655 - Loss: 79.792, Seconds: 3.22
# Epoch   5/100 Batch 6280/6655 - Loss: 77.612, Seconds: 3.40
# Epoch   5/100 Batch 6300/6655 - Loss: 76.715, Seconds: 3.33
# Epoch   5/100 Batch 6320/6655 - Loss: 79.712, Seconds: 3.44
# Epoch   5/100 Batch 6340/6655 - Loss: 82.327, Seconds: 3.41
# Epoch   5/100 Batch 6360/6655 - Loss: 89.802, Seconds: 3.54
# Epoch   5/100 Batch 6380/6655 - Loss: 90.727, Seconds: 3.54
# Epoch   5/100 Batch 6400/6655 - Loss: 88.325, Seconds: 3.32
# Epoch   5/100 Batch 6420/6655 - Loss: 89.123, Seconds: 3.85
# Epoch   5/100 Batch 6440/6655 - Loss: 88.693, Seconds: 3.36
# Epoch   5/100 Batch 6460/6655 - Loss: 86.523, Seconds: 3.69
# Epoch   5/100 Batch 6480/6655 - Loss: 85.858, Seconds: 3.55
# Epoch   5/100 Batch 6500/6655 - Loss: 77.495, Seconds: 3.66
# Epoch   5/100 Batch 6520/6655 - Loss: 72.302, Seconds: 3.64
# Epoch   5/100 Batch 6540/6655 - Loss: 70.836, Seconds: 3.58
# Epoch   5/100 Batch 6560/6655 - Loss: 68.711, Seconds: 3.72
# Epoch   5/100 Batch 6580/6655 - Loss: 85.142, Seconds: 3.68
# Epoch   5/100 Batch 6600/6655 - Loss: 108.053, Seconds: 3.71
# Epoch   5/100 Batch 6620/6655 - Loss: 120.013, Seconds: 4.03
# Epoch   5/100 Batch 6640/6655 - Loss: 121.002, Seconds: 3.74
# Average loss for this update: 21.287
# No Improvement.
# Epoch   6/100 Batch   20/6655 - Loss: 82.861, Seconds: 1.24
# Epoch   6/100 Batch   40/6655 - Loss: 68.283, Seconds: 1.14
# Epoch   6/100 Batch   60/6655 - Loss: 69.013, Seconds: 1.13
# Epoch   6/100 Batch   80/6655 - Loss: 62.864, Seconds: 1.26
# Epoch   6/100 Batch  100/6655 - Loss: 58.611, Seconds: 0.98
# Epoch   6/100 Batch  120/6655 - Loss: 54.007, Seconds: 1.58
# Epoch   6/100 Batch  140/6655 - Loss: 50.648, Seconds: 1.14
# Epoch   6/100 Batch  160/6655 - Loss: 47.550, Seconds: 1.31
# Epoch   6/100 Batch  180/6655 - Loss: 54.689, Seconds: 1.10
# Epoch   6/100 Batch  200/6655 - Loss: 46.543, Seconds: 1.55
# Epoch   6/100 Batch  220/6655 - Loss: 48.196, Seconds: 1.42
# Epoch   6/100 Batch  240/6655 - Loss: 45.188, Seconds: 1.46
# Epoch   6/100 Batch  260/6655 - Loss: 41.794, Seconds: 1.16
# Epoch   6/100 Batch  280/6655 - Loss: 47.239, Seconds: 1.03
# Epoch   6/100 Batch  300/6655 - Loss: 46.649, Seconds: 1.28
# Epoch   6/100 Batch  320/6655 - Loss: 43.539, Seconds: 1.35
# Epoch   6/100 Batch  340/6655 - Loss: 42.853, Seconds: 1.33
# Epoch   6/100 Batch  360/6655 - Loss: 45.485, Seconds: 1.34
# Epoch   6/100 Batch  380/6655 - Loss: 38.973, Seconds: 1.17
# Epoch   6/100 Batch  400/6655 - Loss: 40.564, Seconds: 1.20
# Epoch   6/100 Batch  420/6655 - Loss: 35.263, Seconds: 1.43
# Epoch   6/100 Batch  440/6655 - Loss: 43.560, Seconds: 1.26
# Epoch   6/100 Batch  460/6655 - Loss: 40.842, Seconds: 1.41
# Epoch   6/100 Batch  480/6655 - Loss: 44.439, Seconds: 1.47
# Epoch   6/100 Batch  500/6655 - Loss: 41.177, Seconds: 1.34
# Epoch   6/100 Batch  520/6655 - Loss: 40.308, Seconds: 1.33
# Epoch   6/100 Batch  540/6655 - Loss: 42.652, Seconds: 1.24
# Epoch   6/100 Batch  560/6655 - Loss: 39.294, Seconds: 1.19
# Epoch   6/100 Batch  580/6655 - Loss: 39.885, Seconds: 1.26
# Epoch   6/100 Batch  600/6655 - Loss: 38.090, Seconds: 1.17
# Epoch   6/100 Batch  620/6655 - Loss: 38.740, Seconds: 1.46
# Epoch   6/100 Batch  640/6655 - Loss: 37.208, Seconds: 1.27
# Epoch   6/100 Batch  660/6655 - Loss: 37.277, Seconds: 1.48
# Epoch   6/100 Batch  680/6655 - Loss: 35.238, Seconds: 1.44
# Epoch   6/100 Batch  700/6655 - Loss: 33.731, Seconds: 1.55
# Epoch   6/100 Batch  720/6655 - Loss: 32.040, Seconds: 1.58
# Epoch   6/100 Batch  740/6655 - Loss: 32.724, Seconds: 1.33
# Epoch   6/100 Batch  760/6655 - Loss: 29.851, Seconds: 1.10
# Epoch   6/100 Batch  780/6655 - Loss: 29.510, Seconds: 1.15
# Epoch   6/100 Batch  800/6655 - Loss: 29.700, Seconds: 1.36
# Epoch   6/100 Batch  820/6655 - Loss: 30.638, Seconds: 1.27
# Epoch   6/100 Batch  840/6655 - Loss: 30.210, Seconds: 1.47
# Epoch   6/100 Batch  860/6655 - Loss: 30.855, Seconds: 1.56
# Epoch   6/100 Batch  880/6655 - Loss: 31.325, Seconds: 1.26
# Epoch   6/100 Batch  900/6655 - Loss: 31.611, Seconds: 1.43
# Epoch   6/100 Batch  920/6655 - Loss: 31.294, Seconds: 1.44
# Epoch   6/100 Batch  940/6655 - Loss: 30.059, Seconds: 1.53
# Epoch   6/100 Batch  960/6655 - Loss: 27.909, Seconds: 1.52
# Epoch   6/100 Batch  980/6655 - Loss: 28.669, Seconds: 1.65
# Epoch   6/100 Batch 1000/6655 - Loss: 28.432, Seconds: 1.45
# Epoch   6/100 Batch 1020/6655 - Loss: 30.127, Seconds: 1.36
# Epoch   6/100 Batch 1040/6655 - Loss: 29.468, Seconds: 1.30
# Epoch   6/100 Batch 1060/6655 - Loss: 29.543, Seconds: 1.56
# Epoch   6/100 Batch 1080/6655 - Loss: 35.972, Seconds: 1.49
# Epoch   6/100 Batch 1100/6655 - Loss: 32.810, Seconds: 1.26
# Epoch   6/100 Batch 1120/6655 - Loss: 31.043, Seconds: 1.52
# Epoch   6/100 Batch 1140/6655 - Loss: 31.178, Seconds: 1.17
# Epoch   6/100 Batch 1160/6655 - Loss: 28.598, Seconds: 1.31
# Epoch   6/100 Batch 1180/6655 - Loss: 29.012, Seconds: 1.55
# Epoch   6/100 Batch 1200/6655 - Loss: 28.771, Seconds: 1.62
# Epoch   6/100 Batch 1220/6655 - Loss: 33.054, Seconds: 1.53
# Epoch   6/100 Batch 1240/6655 - Loss: 31.347, Seconds: 1.23
# Epoch   6/100 Batch 1260/6655 - Loss: 32.128, Seconds: 1.49
# Epoch   6/100 Batch 1280/6655 - Loss: 27.449, Seconds: 1.39
# Epoch   6/100 Batch 1300/6655 - Loss: 25.086, Seconds: 1.19
# Epoch   6/100 Batch 1320/6655 - Loss: 24.263, Seconds: 1.32
# Epoch   6/100 Batch 1340/6655 - Loss: 22.454, Seconds: 1.50
# Epoch   6/100 Batch 1360/6655 - Loss: 23.913, Seconds: 1.66
# Epoch   6/100 Batch 1380/6655 - Loss: 23.498, Seconds: 1.29
# Epoch   6/100 Batch 1400/6655 - Loss: 23.967, Seconds: 1.36
# Epoch   6/100 Batch 1420/6655 - Loss: 20.434, Seconds: 1.50
# Epoch   6/100 Batch 1440/6655 - Loss: 22.229, Seconds: 1.50
# Epoch   6/100 Batch 1460/6655 - Loss: 22.832, Seconds: 1.37
# Epoch   6/100 Batch 1480/6655 - Loss: 21.505, Seconds: 1.35
# Epoch   6/100 Batch 1500/6655 - Loss: 20.563, Seconds: 1.40
# Epoch   6/100 Batch 1520/6655 - Loss: 22.126, Seconds: 1.38
# Epoch   6/100 Batch 1540/6655 - Loss: 22.618, Seconds: 1.30
# Epoch   6/100 Batch 1560/6655 - Loss: 22.669, Seconds: 1.19
# Epoch   6/100 Batch 1580/6655 - Loss: 21.647, Seconds: 1.36
# Epoch   6/100 Batch 1600/6655 - Loss: 21.921, Seconds: 1.54
# Epoch   6/100 Batch 1620/6655 - Loss: 21.516, Seconds: 1.43
# Epoch   6/100 Batch 1640/6655 - Loss: 20.570, Seconds: 1.39
# Epoch   6/100 Batch 1660/6655 - Loss: 19.141, Seconds: 1.46
# Epoch   6/100 Batch 1680/6655 - Loss: 19.593, Seconds: 1.49
# Epoch   6/100 Batch 1700/6655 - Loss: 19.643, Seconds: 1.63
# Epoch   6/100 Batch 1720/6655 - Loss: 19.914, Seconds: 1.27
# Epoch   6/100 Batch 1740/6655 - Loss: 21.870, Seconds: 1.59
# Epoch   6/100 Batch 1760/6655 - Loss: 24.027, Seconds: 1.55
# Epoch   6/100 Batch 1780/6655 - Loss: 24.669, Seconds: 1.76
# Epoch   6/100 Batch 1800/6655 - Loss: 23.605, Seconds: 1.46
# Epoch   6/100 Batch 1820/6655 - Loss: 25.655, Seconds: 1.48
# Epoch   6/100 Batch 1840/6655 - Loss: 27.975, Seconds: 1.47
# Epoch   6/100 Batch 1860/6655 - Loss: 26.674, Seconds: 1.50
# Epoch   6/100 Batch 1880/6655 - Loss: 25.370, Seconds: 1.57
# Epoch   6/100 Batch 1900/6655 - Loss: 25.035, Seconds: 1.48
# Epoch   6/100 Batch 1920/6655 - Loss: 22.798, Seconds: 1.66
# Epoch   6/100 Batch 1940/6655 - Loss: 24.571, Seconds: 1.26
# Epoch   6/100 Batch 1960/6655 - Loss: 24.104, Seconds: 1.48
# Epoch   6/100 Batch 1980/6655 - Loss: 24.399, Seconds: 1.75
# Epoch   6/100 Batch 2000/6655 - Loss: 24.424, Seconds: 1.60
# Epoch   6/100 Batch 2020/6655 - Loss: 20.220, Seconds: 1.51
# Epoch   6/100 Batch 2040/6655 - Loss: 21.944, Seconds: 1.50
# Epoch   6/100 Batch 2060/6655 - Loss: 19.395, Seconds: 1.69
# Epoch   6/100 Batch 2080/6655 - Loss: 20.016, Seconds: 1.71
# Epoch   6/100 Batch 2100/6655 - Loss: 21.258, Seconds: 1.67
# Epoch   6/100 Batch 2120/6655 - Loss: 22.572, Seconds: 1.42
# Epoch   6/100 Batch 2140/6655 - Loss: 25.475, Seconds: 1.64
# Epoch   6/100 Batch 2160/6655 - Loss: 21.948, Seconds: 1.27
# Epoch   6/100 Batch 2180/6655 - Loss: 20.780, Seconds: 1.73
# Epoch   6/100 Batch 2200/6655 - Loss: 19.386, Seconds: 1.55
# Average loss for this update: 32.167
# No Improvement.
# Stopping Training.

# %%
checkpoint = "/content/drive/My Drive/best_model_300.ckpt" 

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(checkpoint + '.meta')
    loader.restore(sess, checkpoint)
    names = []
    [names.append(n.name) for n in loaded_graph.as_graph_def().node]
names
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/best_model_300.ckpt
# ['input',
#  'targets',
#  'learning_rate',
#  'keep_prob',
#  'summary_length',
#  'Const',
#  'max_dec_len',
#  'text_length',
#  'ReverseV2/axis',
#  'ReverseV2',
#  'embedding_lookup/params_0',
#  'embedding_lookup/axis',
#  'embedding_lookup',
#  'embedding_lookup/Identity',
#  'encoder_0/DropoutWrapperInit/Const',
#  'encoder_0/DropoutWrapperInit/Const_1',
#  'encoder_0/DropoutWrapperInit_1/Const',
#  'encoder_0/DropoutWrapperInit_1/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/Rank',
#  'encoder_0/bidirectional_rnn/fw/fw/range/start',
#  'encoder_0/bidirectional_rnn/fw/fw/range/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/range',
#  'encoder_0/bidirectional_rnn/fw/fw/concat/values_0',
#  'encoder_0/bidirectional_rnn/fw/fw/concat/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/concat',
#  'encoder_0/bidirectional_rnn/fw/fw/transpose',
#  'encoder_0/bidirectional_rnn/fw/fw/sequence_length',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_0/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape_1',
#  'encoder_0/bidirectional_rnn/fw/fw/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/Equal',
#  'encoder_0/bidirectional_rnn/fw/fw/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/All',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Assert/data_0',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Assert/data_2',
#  'encoder_0/bidirectional_rnn/fw/fw/Assert/Assert',
#  'encoder_0/bidirectional_rnn/fw/fw/CheckSeqLen',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_1',
#  'encoder_0/bidirectional_rnn/fw/fw/Shape_3',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/strided_slice_2',
#  'encoder_0/bidirectional_rnn/fw/fw/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/fw/fw/ExpandDims',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_1',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_1/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_1',
#  'encoder_0/bidirectional_rnn/fw/fw/zeros/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/zeros',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_2',
#  'encoder_0/bidirectional_rnn/fw/fw/Min',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_3',
#  'encoder_0/bidirectional_rnn/fw/fw/Max',
#  'encoder_0/bidirectional_rnn/fw/fw/time',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArray',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArray_1',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/Shape',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/start',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/range',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_0/bidirectional_rnn/fw/fw/Maximum/x',
#  'encoder_0/bidirectional_rnn/fw/fw/Maximum',
#  'encoder_0/bidirectional_rnn/fw/fw/Minimum',
#  'encoder_0/bidirectional_rnn/fw/fw/while/iteration_counter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Enter_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Merge_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less_1/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Less_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/LogicalAnd',
#  'encoder_0/bidirectional_rnn/fw/fw/while/LoopCond',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Switch_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Identity_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add/y',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayReadV3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/GreaterEqual/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/GreaterEqual',
#  'encoder_0/bidirectional_rnn/fw/fw/while/sub/x',
#  'encoder_0/bidirectional_rnn/fw/fw/while/sub/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/sub',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/Shape',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/min',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/max',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/random_uniform',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/sub/x',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/sub',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/truediv/x',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/truediv',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/GreaterEqual',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/mul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/Cast',
#  'encoder_0/bidirectional_rnn/fw/fw/while/dropout/mul_1',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/Assign',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/kernel/read',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/Assign',
#  'encoder_0/bidirectional_rnn/fw/lstm_cell/bias/read',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/concat/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/concat',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Const',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/split/split_dim',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/split',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/add/y',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/add',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/mul',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/mul_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/add_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/lstm_cell/mul_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Select_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_0/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add_1/y',
#  'encoder_0/bidirectional_rnn/fw/fw/while/add_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/NextIteration_4',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_1',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_2',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_3',
#  'encoder_0/bidirectional_rnn/fw/fw/while/Exit_4',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/range/start',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/range/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/range',
#  'encoder_0/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_0/bidirectional_rnn/fw/fw/Const_4',
#  'encoder_0/bidirectional_rnn/fw/fw/Rank_1',
#  'encoder_0/bidirectional_rnn/fw/fw/range_1/start',
#  'encoder_0/bidirectional_rnn/fw/fw/range_1/delta',
#  'encoder_0/bidirectional_rnn/fw/fw/range_1',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_2/values_0',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_2/axis',
#  'encoder_0/bidirectional_rnn/fw/fw/concat_2',
#  'encoder_0/bidirectional_rnn/fw/fw/transpose_1',
#  'encoder_0/bidirectional_rnn/bw/ReverseSequence',
#  'encoder_0/bidirectional_rnn/bw/bw/Rank',
#  'encoder_0/bidirectional_rnn/bw/bw/range/start',
#  'encoder_0/bidirectional_rnn/bw/bw/range/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/range',
#  'encoder_0/bidirectional_rnn/bw/bw/concat/values_0',
#  'encoder_0/bidirectional_rnn/bw/bw/concat/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/concat',
#  'encoder_0/bidirectional_rnn/bw/bw/transpose',
#  'encoder_0/bidirectional_rnn/bw/bw/sequence_length',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_0/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape_1',
#  'encoder_0/bidirectional_rnn/bw/bw/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/Equal',
#  'encoder_0/bidirectional_rnn/bw/bw/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/All',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Const_1',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Assert/data_0',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Assert/data_2',
#  'encoder_0/bidirectional_rnn/bw/bw/Assert/Assert',
#  'encoder_0/bidirectional_rnn/bw/bw/CheckSeqLen',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_1',
#  'encoder_0/bidirectional_rnn/bw/bw/Shape_3',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/strided_slice_2',
#  'encoder_0/bidirectional_rnn/bw/bw/ExpandDims/dim',
#  'encoder_0/bidirectional_rnn/bw/bw/ExpandDims',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_1',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_1/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_1',
#  'encoder_0/bidirectional_rnn/bw/bw/zeros/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/zeros',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_2',
#  'encoder_0/bidirectional_rnn/bw/bw/Min',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_3',
#  'encoder_0/bidirectional_rnn/bw/bw/Max',
#  'encoder_0/bidirectional_rnn/bw/bw/time',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArray',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArray_1',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/Shape',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/start',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/range',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_0/bidirectional_rnn/bw/bw/Maximum/x',
#  'encoder_0/bidirectional_rnn/bw/bw/Maximum',
#  'encoder_0/bidirectional_rnn/bw/bw/Minimum',
#  'encoder_0/bidirectional_rnn/bw/bw/while/iteration_counter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Enter_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Merge_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less_1/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Less_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/LogicalAnd',
#  'encoder_0/bidirectional_rnn/bw/bw/while/LoopCond',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Switch_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Identity_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add/y',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayReadV3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/GreaterEqual/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/GreaterEqual',
#  'encoder_0/bidirectional_rnn/bw/bw/while/sub/x',
#  'encoder_0/bidirectional_rnn/bw/bw/while/sub/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/sub',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/Shape',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/min',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/max',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/random_uniform',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/sub/x',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/sub',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/truediv/x',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/truediv',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/GreaterEqual',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/mul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/Cast',
#  'encoder_0/bidirectional_rnn/bw/bw/while/dropout/mul_1',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/Assign',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/kernel/read',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/Assign',
#  'encoder_0/bidirectional_rnn/bw/lstm_cell/bias/read',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/concat/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/concat',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Const',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/split/split_dim',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/split',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/add/y',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/add',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/mul',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/mul_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/add_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/lstm_cell/mul_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Select_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_0/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add_1/y',
#  'encoder_0/bidirectional_rnn/bw/bw/while/add_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/NextIteration_4',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_1',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_2',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_3',
#  'encoder_0/bidirectional_rnn/bw/bw/while/Exit_4',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/range/start',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/range/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/range',
#  'encoder_0/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_0/bidirectional_rnn/bw/bw/Const_4',
#  'encoder_0/bidirectional_rnn/bw/bw/Rank_1',
#  'encoder_0/bidirectional_rnn/bw/bw/range_1/start',
#  'encoder_0/bidirectional_rnn/bw/bw/range_1/delta',
#  'encoder_0/bidirectional_rnn/bw/bw/range_1',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_2/values_0',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_2/axis',
#  'encoder_0/bidirectional_rnn/bw/bw/concat_2',
#  'encoder_0/bidirectional_rnn/bw/bw/transpose_1',
#  'encoder_0/ReverseSequence',
#  'encoder_1/DropoutWrapperInit/Const',
#  'encoder_1/DropoutWrapperInit/Const_1',
#  'encoder_1/DropoutWrapperInit_1/Const',
#  'encoder_1/DropoutWrapperInit_1/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/Rank',
#  'encoder_1/bidirectional_rnn/fw/fw/range/start',
#  'encoder_1/bidirectional_rnn/fw/fw/range/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/range',
#  'encoder_1/bidirectional_rnn/fw/fw/concat/values_0',
#  'encoder_1/bidirectional_rnn/fw/fw/concat/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/concat',
#  'encoder_1/bidirectional_rnn/fw/fw/transpose',
#  'encoder_1/bidirectional_rnn/fw/fw/sequence_length',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_1/bidirectional_rnn/fw/fw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape_1',
#  'encoder_1/bidirectional_rnn/fw/fw/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/Equal',
#  'encoder_1/bidirectional_rnn/fw/fw/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/All',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Assert/data_0',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Assert/data_2',
#  'encoder_1/bidirectional_rnn/fw/fw/Assert/Assert',
#  'encoder_1/bidirectional_rnn/fw/fw/CheckSeqLen',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_1',
#  'encoder_1/bidirectional_rnn/fw/fw/Shape_3',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/strided_slice_2',
#  'encoder_1/bidirectional_rnn/fw/fw/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/fw/fw/ExpandDims',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_1/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_1',
#  'encoder_1/bidirectional_rnn/fw/fw/zeros/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/zeros',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_2',
#  'encoder_1/bidirectional_rnn/fw/fw/Min',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_3',
#  'encoder_1/bidirectional_rnn/fw/fw/Max',
#  'encoder_1/bidirectional_rnn/fw/fw/time',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArray',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArray_1',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/Shape',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/strided_slice',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/start',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/range/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/range',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_1/bidirectional_rnn/fw/fw/Maximum/x',
#  'encoder_1/bidirectional_rnn/fw/fw/Maximum',
#  'encoder_1/bidirectional_rnn/fw/fw/Minimum',
#  'encoder_1/bidirectional_rnn/fw/fw/while/iteration_counter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Enter_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Merge_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less_1/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Less_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/LogicalAnd',
#  'encoder_1/bidirectional_rnn/fw/fw/while/LoopCond',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Switch_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Identity_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayReadV3/Enter_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayReadV3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/GreaterEqual/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/GreaterEqual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/sub/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/sub/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/sub',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/Shape',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/min',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/max',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/random_uniform',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/sub/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/sub',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/truediv/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/truediv',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/GreaterEqual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/mul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/Cast',
#  'encoder_1/bidirectional_rnn/fw/fw/while/dropout/mul_1',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/Assign',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/kernel/read',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Initializer/zeros',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/Assign',
#  'encoder_1/bidirectional_rnn/fw/lstm_cell/bias/read',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/concat/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/concat',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/MatMul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/BiasAdd',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/split/split_dim',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/split',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/add/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/add',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/mul',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/mul_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/add_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Sigmoid_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/Tanh_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/lstm_cell/mul_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Select_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_1/bidirectional_rnn/fw/fw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add_1/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/add_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/NextIteration_4',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_2',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/range/start',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/range/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/range',
#  'encoder_1/bidirectional_rnn/fw/fw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_1/bidirectional_rnn/fw/fw/Const_4',
#  'encoder_1/bidirectional_rnn/fw/fw/Rank_1',
#  'encoder_1/bidirectional_rnn/fw/fw/range_1/start',
#  'encoder_1/bidirectional_rnn/fw/fw/range_1/delta',
#  'encoder_1/bidirectional_rnn/fw/fw/range_1',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_2/values_0',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_2/axis',
#  'encoder_1/bidirectional_rnn/fw/fw/concat_2',
#  'encoder_1/bidirectional_rnn/fw/fw/transpose_1',
#  'encoder_1/bidirectional_rnn/bw/ReverseSequence',
#  'encoder_1/bidirectional_rnn/bw/bw/Rank',
#  'encoder_1/bidirectional_rnn/bw/bw/range/start',
#  'encoder_1/bidirectional_rnn/bw/bw/range/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/range',
#  'encoder_1/bidirectional_rnn/bw/bw/concat/values_0',
#  'encoder_1/bidirectional_rnn/bw/bw/concat/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/concat',
#  'encoder_1/bidirectional_rnn/bw/bw/transpose',
#  'encoder_1/bidirectional_rnn/bw/bw/sequence_length',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_2',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/ExpandDims_3',
#  'encoder_1/bidirectional_rnn/bw/bw/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape_1',
#  'encoder_1/bidirectional_rnn/bw/bw/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/Equal',
#  'encoder_1/bidirectional_rnn/bw/bw/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/All',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Const_1',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Assert/data_0',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Assert/data_2',
#  'encoder_1/bidirectional_rnn/bw/bw/Assert/Assert',
#  'encoder_1/bidirectional_rnn/bw/bw/CheckSeqLen',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_1',
#  'encoder_1/bidirectional_rnn/bw/bw/Shape_3',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/strided_slice_2',
#  'encoder_1/bidirectional_rnn/bw/bw/ExpandDims/dim',
#  'encoder_1/bidirectional_rnn/bw/bw/ExpandDims',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_1',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_1/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_1',
#  'encoder_1/bidirectional_rnn/bw/bw/zeros/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/zeros',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_2',
#  'encoder_1/bidirectional_rnn/bw/bw/Min',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_3',
#  'encoder_1/bidirectional_rnn/bw/bw/Max',
#  'encoder_1/bidirectional_rnn/bw/bw/time',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArray',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArray_1',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/Shape',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_1',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice/stack_2',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/strided_slice',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/start',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/range/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/range',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayUnstack/TensorArrayScatter/TensorArrayScatterV3',
#  'encoder_1/bidirectional_rnn/bw/bw/Maximum/x',
#  'encoder_1/bidirectional_rnn/bw/bw/Maximum',
#  'encoder_1/bidirectional_rnn/bw/bw/Minimum',
#  'encoder_1/bidirectional_rnn/bw/bw/while/iteration_counter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Enter_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Merge_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less_1/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Less_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/LogicalAnd',
#  'encoder_1/bidirectional_rnn/bw/bw/while/LoopCond',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Switch_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Identity_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add/y',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayReadV3/Enter_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayReadV3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/GreaterEqual/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/GreaterEqual',
#  'encoder_1/bidirectional_rnn/bw/bw/while/sub/x',
#  'encoder_1/bidirectional_rnn/bw/bw/while/sub/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/sub',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/Shape',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/min',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/max',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/random_uniform',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/sub/x',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/sub',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/truediv/x',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/truediv',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/GreaterEqual',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/mul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/Cast',
#  'encoder_1/bidirectional_rnn/bw/bw/while/dropout/mul_1',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/shape',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/min',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/max',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/RandomUniform',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/sub',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform/mul',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Initializer/random_uniform',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/Assign',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/kernel/read',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/shape_as_tensor',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros/Const',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Initializer/zeros',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/Assign',
#  'encoder_1/bidirectional_rnn/bw/lstm_cell/bias/read',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/concat/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/concat',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/MatMul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/BiasAdd',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Const',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/split/split_dim',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/split',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/add/y',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/add',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/mul',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/mul_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/add_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Sigmoid_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/Tanh_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/lstm_cell/mul_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Select_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3/Enter',
#  'encoder_1/bidirectional_rnn/bw/bw/while/TensorArrayWrite/TensorArrayWriteV3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add_1/y',
#  'encoder_1/bidirectional_rnn/bw/bw/while/add_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/NextIteration_4',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_1',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_2',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_3',
#  'encoder_1/bidirectional_rnn/bw/bw/while/Exit_4',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArraySizeV3',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/range/start',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/range/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/range',
#  'encoder_1/bidirectional_rnn/bw/bw/TensorArrayStack/TensorArrayGatherV3',
#  'encoder_1/bidirectional_rnn/bw/bw/Const_4',
#  'encoder_1/bidirectional_rnn/bw/bw/Rank_1',
#  'encoder_1/bidirectional_rnn/bw/bw/range_1/start',
#  'encoder_1/bidirectional_rnn/bw/bw/range_1/delta',
#  'encoder_1/bidirectional_rnn/bw/bw/range_1',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_2/values_0',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_2/axis',
#  'encoder_1/bidirectional_rnn/bw/bw/concat_2',
#  'encoder_1/bidirectional_rnn/bw/bw/transpose_1',
#  'encoder_1/ReverseSequence',
#  'concat/axis',
#  'concat',
#  'StridedSlice/begin',
#  'StridedSlice/end',
#  'StridedSlice/strides',
#  'StridedSlice',
#  'Fill/dims',
#  'Fill/value',
#  'Fill',
#  'concat_1/axis',
#  'concat_1',
#  'embedding_lookup_1/params_0',
#  'embedding_lookup_1/axis',
#  'embedding_lookup_1',
#  'embedding_lookup_1/Identity',
#  'decoder_0/DropoutWrapperInit/Const',
#  'decoder_0/DropoutWrapperInit/Const_1',
#  'decoder_1/DropoutWrapperInit/Const',
#  'decoder_1/DropoutWrapperInit/Const_1',
#  'BahdanauAttention/Shape',
#  'BahdanauAttention/strided_slice/stack',
#  'BahdanauAttention/strided_slice/stack_1',
#  'BahdanauAttention/strided_slice/stack_2',
#  'BahdanauAttention/strided_slice',
#  'BahdanauAttention/SequenceMask/Const',
#  'BahdanauAttention/SequenceMask/Const_1',
#  'BahdanauAttention/SequenceMask/Range',
#  'BahdanauAttention/SequenceMask/ExpandDims/dim',
#  'BahdanauAttention/SequenceMask/ExpandDims',
#  'BahdanauAttention/SequenceMask/Cast',
#  'BahdanauAttention/SequenceMask/Less',
#  'BahdanauAttention/SequenceMask/Cast_1',
#  'BahdanauAttention/ones/shape_as_tensor',
#  'BahdanauAttention/ones/Const',
#  'BahdanauAttention/ones',
#  'BahdanauAttention/Shape_1',
#  'BahdanauAttention/concat/axis',
#  'BahdanauAttention/concat',
#  'BahdanauAttention/Reshape',
#  'BahdanauAttention/mul',
#  'memory_layer/kernel/Initializer/random_uniform/shape',
#  'memory_layer/kernel/Initializer/random_uniform/min',
#  'memory_layer/kernel/Initializer/random_uniform/max',
#  'memory_layer/kernel/Initializer/random_uniform/RandomUniform',
#  'memory_layer/kernel/Initializer/random_uniform/sub',
#  'memory_layer/kernel/Initializer/random_uniform/mul',
#  'memory_layer/kernel/Initializer/random_uniform',
#  'memory_layer/kernel',
#  'memory_layer/kernel/Assign',
#  'memory_layer/kernel/read',
#  'BahdanauAttention/memory_layer/Tensordot/axes',
#  'BahdanauAttention/memory_layer/Tensordot/free',
#  'BahdanauAttention/memory_layer/Tensordot/Shape',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2/axis',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2_1/axis',
#  'BahdanauAttention/memory_layer/Tensordot/GatherV2_1',
#  'BahdanauAttention/memory_layer/Tensordot/Const',
#  'BahdanauAttention/memory_layer/Tensordot/Prod',
#  'BahdanauAttention/memory_layer/Tensordot/Const_1',
#  'BahdanauAttention/memory_layer/Tensordot/Prod_1',
#  'BahdanauAttention/memory_layer/Tensordot/concat/axis',
#  'BahdanauAttention/memory_layer/Tensordot/concat',
#  'BahdanauAttention/memory_layer/Tensordot/stack',
#  'BahdanauAttention/memory_layer/Tensordot/transpose',
#  'BahdanauAttention/memory_layer/Tensordot/Reshape',
#  'BahdanauAttention/memory_layer/Tensordot/transpose_1/perm',
#  'BahdanauAttention/memory_layer/Tensordot/transpose_1',
#  'BahdanauAttention/memory_layer/Tensordot/Reshape_1/shape',
#  'BahdanauAttention/memory_layer/Tensordot/Reshape_1',
#  'BahdanauAttention/memory_layer/Tensordot/MatMul',
#  'BahdanauAttention/memory_layer/Tensordot/Const_2',
#  'BahdanauAttention/memory_layer/Tensordot/concat_1/axis',
#  'BahdanauAttention/memory_layer/Tensordot/concat_1',
#  'BahdanauAttention/memory_layer/Tensordot',
#  'BahdanauAttention/Shape_2',
#  'BahdanauAttention/strided_slice_1/stack',
#  'BahdanauAttention/strided_slice_1/stack_1',
#  'BahdanauAttention/strided_slice_1/stack_2',
#  'BahdanauAttention/strided_slice_1',
#  'BahdanauAttention/Shape_3',
#  'BahdanauAttention/strided_slice_2/stack',
#  'BahdanauAttention/strided_slice_2/stack_1',
#  'BahdanauAttention/strided_slice_2/stack_2',
#  'BahdanauAttention/strided_slice_2',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_1',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat/axis',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros/Const',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_2',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_3',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_4',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_5',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat_1/axis',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/concat_1',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1/Const',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/zeros_1',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_6',
#  'AttentionWrapperZeroState/DropoutWrapperZeroState/LSTMCellZeroState/Const_7',
#  'AttentionWrapperZeroState/assert_equal_1/x',
#  'AttentionWrapperZeroState/assert_equal_1/Equal',
#  'AttentionWrapperZeroState/assert_equal_1/Const',
#  'AttentionWrapperZeroState/assert_equal_1/All',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const_1',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const_2',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Const_3',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_0',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_1',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_2',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert/data_4',
#  'AttentionWrapperZeroState/assert_equal_1/Assert/Assert',
#  'AttentionWrapperZeroState/checked_cell_state',
#  'AttentionWrapperZeroState/checked_cell_state_1',
#  'AttentionWrapperZeroState/Const',
#  'AttentionWrapperZeroState/ExpandDims/dim',
#  'AttentionWrapperZeroState/ExpandDims',
#  'AttentionWrapperZeroState/concat/axis',
#  'AttentionWrapperZeroState/concat',
#  'AttentionWrapperZeroState/zeros/Const',
#  'AttentionWrapperZeroState/zeros',
#  'AttentionWrapperZeroState/Const_1',
#  'AttentionWrapperZeroState/ExpandDims_1/dim',
#  'AttentionWrapperZeroState/ExpandDims_1',
#  'AttentionWrapperZeroState/zeros_1',
#  'AttentionWrapperZeroState/Const_2',
#  'AttentionWrapperZeroState/Const_3',
#  'AttentionWrapperZeroState/concat_1/axis',
#  'AttentionWrapperZeroState/concat_1',
#  'AttentionWrapperZeroState/zeros_2/Const',
#  'AttentionWrapperZeroState/zeros_2',
#  'AttentionWrapperZeroState/Const_4',
#  'AttentionWrapperZeroState/Const_5',
#  'AttentionWrapperZeroState/Const_6',
#  'AttentionWrapperZeroState/ExpandDims_2/dim',
#  'AttentionWrapperZeroState/ExpandDims_2',
#  'AttentionWrapperZeroState/concat_2/axis',
#  'AttentionWrapperZeroState/concat_2',
#  'AttentionWrapperZeroState/zeros_3/Const',
#  'AttentionWrapperZeroState/zeros_3',
#  'AttentionWrapperZeroState/Const_7',
#  'AttentionWrapperZeroState/ExpandDims_3/dim',
#  'AttentionWrapperZeroState/ExpandDims_3',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/Size/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/Size',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/is_rank/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/is_rank',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Equal/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Equal/y',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Equal',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/equal_1/x',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/equal_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/exclude_partial_shape',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape/shape_tensor_equal',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/is_shape',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Const_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Assert/data_0',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Assert/data_1',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/assert_shape/Assert',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_3/Identity',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/Size/Const',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/Size',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/is_rank/actual',
#  'encoder_1/bidirectional_rnn/fw/fw/while/Exit_4/assert_shape/is_shape/is_rank',
#  ...]

# %% [markdown]
# **Making Our Own Summaries**
#
# To see the quality of the summaries that this model can generate, you can either create your own review, or use a review from the dataset. You can set the length of the summary to a fixed value, or use a random value like I have here.

# %%
def text_to_seq(text):
    '''Prepare the text for the model'''
    
    text = clean_text(text)
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in text.split()]

# %%
# Create your own review or use one from the dataset
#input_sentence = "I have never eaten an apple before, but this red one was nice. \
                  #I think that I will try a green apple next time."
#text = text_to_seq(input_sentence)
random = np.random.randint(0,len(clean_texts))
input_sentence = clean_texts[random]
#input_sentence = 'Superb earphones, nice product'
text = text_to_seq(clean_texts[random])
#text = text_to_seq("Superb product, This earphone from daraz.pk is one of the finnest qualit headphones I have ordered ever")
checkpoint = "/content/drive/My Drive/best_model_300.ckpt"

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(checkpoint + '.meta')
    loader.restore(sess, checkpoint)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    text_length = loaded_graph.get_tensor_by_name('text_length:0')
    summary_length = loaded_graph.get_tensor_by_name('summary_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
    
    #Multiply by batch_size to match the model's input parameters
    answer_logits = sess.run(logits, {input_data: [text]*batch_size, 
                                      summary_length: [np.random.randint(5,8)], 
                                      text_length: [len(text)]*batch_size,
                                      keep_prob: 1.0})[0] 

# Remove the padding from the tweet
pad = vocab_to_int["<PAD>"] 

print('Original Text:', data_train.Text[random])
#print('Original Text:', text)
print('Original summary:', data_train.Summary[random])#clean_summaries[random]
#print('Original summary:', text)#clean_summaries[random]

#print('\nText')
#print('  Word Ids:    {}'.format([i for i in text]))
#print('  Input Words: {}'.format(" ".join([int_to_vocab[i] for i in text])))

print('\nPredicted Summary')
#print('  Word Ids:       {}'.format([i for i in answer_logits if i != pad]))
print('Response Words: {}'.format(" ".join([int_to_vocab[i] for i in answer_logits if i != pad])))
# Out:
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/best_model_300.ckpt
# Original Text: I bought a couple of these from my local grocery store and was so sorry I had not bought more. These are so gooey,chewy and full of flavor. I never did try them warm just straight out of the bag! I have been looking for them for the last few months and have not had any luck in finding them in stock. So as always Amazon comes to the rescue and was able to order them. Like one of the other reviewers pointed out "If you like hard and crunchy these are not for you".
# Original summary: Wow....
#
# Predicted Summary
# Response Words: hard to find

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = [['So', 'easy', 'so', 'good','and','all','natural']]
candidate = ['great', 'hot', 'snack']
score = sentence_bleu(reference, candidate)
print(score)
# Out:
# 0

# %%
# !pip install sumeval
# !python -m spacy download en
# Out:
# Collecting sumeval
#   Downloading https://files.pythonhosted.org/packages/e6/87/bfc0f9397b9421305863edfdd2dbea637e47204976cb5473535c856338f4/sumeval-0.2.2.tar.gz (80kB)
#      |████████████████████████████████| 81kB 6.1MB/s
# Requirement already satisfied: plac>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from sumeval) (0.9.6)
# Collecting sacrebleu>=1.3.2
#   Downloading https://files.pythonhosted.org/packages/45/31/1a135b964c169984b27fb2f7a50280fa7f8e6d9d404d8a9e596180487fd1/sacrebleu-1.4.3-py3-none-any.whl
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from sacrebleu>=1.3.2->sumeval) (3.6.6)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/91/db/7bc703c0760df726839e0699b7f78a4d8217fdc9c7fcb1b51b39c5a22a4e/portalocker-1.5.2-py2.py3-none-any.whl
# Building wheels for collected packages: sumeval
#   Building wheel for sumeval (setup.py) ... done
#   Created wheel for sumeval: filename=sumeval-0.2.2-cp36-none-any.whl size=54535 sha256=4a7e735ff56f614a6a9aca2f9d08e5342c97ee01fd8b561963101ae3e401b373
#   Stored in directory: /root/.cache/pip/wheels/7b/6f/57/19ceecab21445c88f3c565735fa1887b4cd18d340c972eb445
# Successfully built sumeval
# Installing collected packages: portalocker, sacrebleu, sumeval
# Successfully installed portalocker-1.5.2 sacrebleu-1.4.3 sumeval-0.2.2
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /usr/local/lib/python3.6/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
#https://github.com/chakki-works/sumeval
#https://github.com/Tian312/awesome-text-summarization

from sumeval.metrics.rouge import RougeCalculator

refrence_summary = "So easy, so good and all natural"
model_summary = "great hot snack"

rouge = RougeCalculator(stopwords=True, lang="en")

rouge_1 = rouge.rouge_n(
            summary=model_summary,
            references=refrence_summary,
            n=1)

rouge_2 = rouge.rouge_n(
            summary=model_summary,
            references=[refrence_summary],
            n=2)

rouge_l = rouge.rouge_l(
            summary=model_summary,
            references=[refrence_summary])

# You need spaCy to calculate ROUGE-BE

rouge_be = rouge.rouge_be(
            summary=model_summary,
            references=[refrence_summary])

print("ROUGE-1: {}, ROUGE-2: {}, ROUGE-L: {}, ROUGE-BE: {}".format(
    rouge_1, rouge_2, rouge_l, rouge_be
).replace(", ", "\n"))
# Out:
# b.great=(amod)=>snack
# b.hot=(amod)=>snack
# ROUGE-1: 0
# ROUGE-2: 0
# ROUGE-L: 0
# ROUGE-BE: 0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
tfidf_vectorizer = TfidfVectorizer()

sentence = ("""My little Chihuahua and Jack Russell mix just loves these! She 
gobbles them up! They are a perfect
size for her small mouth. According
to her, they are very tasty.""","")
model = ("My Dog Loves Them!","")
summary = ("Chihuahua mix perfect","")

tfidf_matrix_sentence = tfidf_vectorizer.fit_transform(sentence) 
tfidf_matrix_model = tfidf_vectorizer.transform(model) 
tfidf_matrix_summary = tfidf_vectorizer.transform(summary) 


cosine = cosine_similarity(tfidf_matrix_sentence, tfidf_matrix_model)
print(cosine)

cosine = cosine_similarity(tfidf_matrix_sentence, tfidf_matrix_summary)
print(cosine)
# Out:
# [[0.29277002 0.        ]
#  [0.         0.        ]]
# [[0.29277002 0.        ]
#  [0.         0.        ]]

# %% [markdown]
# ***Summary***
#
# I hope that you found this project to be rather interesting and informative. One of my main recommendations for working with this dataset and model is either use a GPU, a subset of the dataset, or plenty of time to train your model. As you might be able to expect, the model will not be able to make good predictions just by seeing many reviews, it needs so see the reviews many times to be able to understand the relationship between words and between descriptions & summaries.
#
# In short, I'm pleased with how well this model performs. After creating numerous reviews and checking those from the dataset, I can happily say that most of the generated summaries are appropriate, some of them are great, and some of them make mistakes. I'll try to improve this model and if it gets better, I'll update my GitHub.
#
# Thanks for reading!
